# %%
import sys
sys.path.append('../dataset/')
sys.path.append('../network/')
sys.path.append('../model/')

import os
import glob
import time
import torch
import logging
import argparse
import numpy as np
import pandas as pd
import torch.optim as optim
import torch.nn as nn
import torch
import seaborn as sns

from pathlib import Path
from main_loading import *
from main_network import *
from main_model_rec import *
from main_model_one_class import *
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# > Modified things in local:
# - Changed the `network/main_network.py`, add a new term rep_dim and changed them all to 2.

# %% [markdown]
# # 0. Variable Definitions

# %%
label_dict ={0: 'tshirt', 
                1: 'trouser', 
                2: 'pullover', 
                3: 'dress', 
                4: 'coat',
                5: 'sandal', 
                6: 'shirt', 
                7: 'sneaker', 
                8: 'bag', 
                9: 'boot'}

# %%
# For data
root = '/net/leksai/data/FashionMNIST'
loader_name = 'fmnist'
loader_eval_name = 'fmnist_eval'
label_normal = (0,)
label_abnormal = (7,)
ratio_abnormal = 0

# For model
net_name = 'fmnist_LeNet_rec'
optimizer_ = 'rec'
eta = 0.1
optimizer_name = 'adam'
lr = 0.0001
ae_lr = 0.001
n_epochs = 150
ae_n_epochs = 150
lr_milestones = (50, 100, 150)
batch_size = 128
weight_decay = 0.5e-6
ae_weight_decay = 0.5e-3
device_no = 3
device = 'cuda:3'
n_jobs_dataloader = 0
save_ae = True
load_ae = False
log_path = 'misc/rec_fmnist_0_7.log'
model_path = 'misc/rec_fmnist_0_7.tar'

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler = logging.FileHandler(log_path)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %% [markdown]
# # 1. Load Dataset

# %%
dataset = load_dataset(loader_name=loader_name,
                       root=root,
                       label_normal=label_normal,
                       label_abnormal=label_abnormal,
                       ratio_abnormal=ratio_abnormal)
# Out:
# Loading dataset for you!
# Almost loaded!

# %% [markdown]
# # 2. Load Model

# %%
model = RecModel(optimizer_, eta)
model.set_network(net_name)

# %%
model.train(dataset, eta, optimizer_name, lr, n_epochs, lr_milestones,
            batch_size, weight_decay, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:Hey I am loading net for you!
# Learning rate: 0.0001
# INFO:root:Setting hyper-parameters!
# INFO:root:Starting training...
# INFO:root:| Epoch: 001/150 | Train Time: 2.168s | Train Loss: 0.184840 |
# INFO:root:| Epoch: 002/150 | Train Time: 2.151s | Train Loss: 0.084499 |
# INFO:root:| Epoch: 003/150 | Train Time: 2.105s | Train Loss: 0.053877 |
# INFO:root:| Epoch: 004/150 | Train Time: 2.084s | Train Loss: 0.043053 |
# INFO:root:| Epoch: 005/150 | Train Time: 2.208s | Train Loss: 0.038715 |
# INFO:root:| Epoch: 006/150 | Train Time: 2.240s | Train Loss: 0.036097 |
# INFO:root:| Epoch: 007/150 | Train Time: 2.202s | Train Loss: 0.034799 |
# INFO:root:| Epoch: 008/150 | Train Time: 2.091s | Train Loss: 0.033787 |
# INFO:root:| Epoch: 009/150 | Train Time: 2.113s | Train Loss: 0.032587 |
# INFO:root:| Epoch: 010/150 | Train Time: 2.186s | Train Loss: 0.032172 |
# INFO:root:| Epoch: 011/150 | Train Time: 2.089s | Train Loss: 0.031262 |
# INFO:root:| Epoch: 012/150 | Train Time: 2.119s | Train Loss: 0.030901 |
# INFO:root:| Epoch: 013/150 | Train Time: 2.060s | Train Loss: 0.030254 |
# INFO:root:| Epoch: 014/150 | Train Time: 2.136s | Train Loss: 0.030510 |
# INFO:root:| Epoch: 015/150 | Train Time: 2.195s | Train Loss: 0.029703 |
# INFO:root:| Epoch: 016/150 | Train Time: 2.118s | Train Loss: 0.029335 |
# INFO:root:| Epoch: 017/150 | Train Time: 2.092s | Train Loss: 0.029017 |
# INFO:root:| Epoch: 018/150 | Train Time: 2.180s | Train Loss: 0.028759 |
# INFO:root:| Epoch: 019/150 | Train Time: 2.114s | Train Loss: 0.028254 |
# INFO:root:| Epoch: 020/150 | Train Time: 2.144s | Train Loss: 0.028044 |
# INFO:root:| Epoch: 021/150 | Train Time: 2.112s | Train Loss: 0.027614 |
# INFO:root:| Epoch: 022/150 | Train Time: 2.094s | Train Loss: 0.027521 |
# INFO:root:| Epoch: 023/150 | Train Time: 2.131s | Train Loss: 0.027193 |
# INFO:root:| Epoch: 024/150 | Train Time: 2.164s | Train Loss: 0.026781 |
# INFO:root:| Epoch: 025/150 | Train Time: 2.227s | Train Loss: 0.026842 |
# INFO:root:| Epoch: 026/150 | Train Time: 2.104s | Train Loss: 0.026436 |
# INFO:root:| Epoch: 027/150 | Train Time: 2.102s | Train Loss: 0.026576 |
# INFO:root:| Epoch: 028/150 | Train Time: 2.054s | Train Loss: 0.026247 |
# INFO:root:| Epoch: 029/150 | Train Time: 2.124s | Train Loss: 0.026109 |
# INFO:root:| Epoch: 030/150 | Train Time: 2.247s | Train Loss: 0.025928 |
# INFO:root:| Epoch: 031/150 | Train Time: 2.155s | Train Loss: 0.025956 |
# INFO:root:| Epoch: 032/150 | Train Time: 2.139s | Train Loss: 0.025744 |
# INFO:root:| Epoch: 033/150 | Train Time: 2.192s | Train Loss: 0.025702 |
# INFO:root:| Epoch: 034/150 | Train Time: 2.086s | Train Loss: 0.025473 |
# INFO:root:| Epoch: 035/150 | Train Time: 2.095s | Train Loss: 0.025467 |
# INFO:root:| Epoch: 036/150 | Train Time: 2.134s | Train Loss: 0.025470 |
# INFO:root:| Epoch: 037/150 | Train Time: 2.148s | Train Loss: 0.025434 |
# INFO:root:| Epoch: 038/150 | Train Time: 2.104s | Train Loss: 0.025325 |
# INFO:root:| Epoch: 039/150 | Train Time: 2.117s | Train Loss: 0.025288 |
# INFO:root:| Epoch: 040/150 | Train Time: 2.172s | Train Loss: 0.024884 |
# INFO:root:| Epoch: 041/150 | Train Time: 2.164s | Train Loss: 0.025098 |
# INFO:root:| Epoch: 042/150 | Train Time: 2.191s | Train Loss: 0.024993 |
# INFO:root:| Epoch: 043/150 | Train Time: 2.137s | Train Loss: 0.024840 |
# INFO:root:| Epoch: 044/150 | Train Time: 2.132s | Train Loss: 0.024983 |
# INFO:root:| Epoch: 045/150 | Train Time: 2.082s | Train Loss: 0.024788 |
# INFO:root:| Epoch: 046/150 | Train Time: 2.102s | Train Loss: 0.024779 |
# INFO:root:| Epoch: 047/150 | Train Time: 2.085s | Train Loss: 0.024739 |
# INFO:root:| Epoch: 048/150 | Train Time: 2.181s | Train Loss: 0.024616 |
# INFO:root:| Epoch: 049/150 | Train Time: 2.131s | Train Loss: 0.024620 |
# INFO:root:| Epoch: 050/150 | Train Time: 2.100s | Train Loss: 0.024589 |
# INFO:root:  LR scheduler: new learning rate is 1e-06
# INFO:root:| Epoch: 051/150 | Train Time: 2.066s | Train Loss: 0.024269 |
# INFO:root:| Epoch: 052/150 | Train Time: 2.078s | Train Loss: 0.024258 |
# INFO:root:| Epoch: 053/150 | Train Time: 2.048s | Train Loss: 0.024297 |
# INFO:root:| Epoch: 054/150 | Train Time: 2.069s | Train Loss: 0.024258 |
# INFO:root:| Epoch: 055/150 | Train Time: 2.034s | Train Loss: 0.024326 |
# INFO:root:| Epoch: 056/150 | Train Time: 2.072s | Train Loss: 0.024254 |
# INFO:root:| Epoch: 057/150 | Train Time: 2.058s | Train Loss: 0.024223 |
# INFO:root:| Epoch: 058/150 | Train Time: 2.105s | Train Loss: 0.024220 |
# INFO:root:| Epoch: 059/150 | Train Time: 2.091s | Train Loss: 0.024106 |
# INFO:root:| Epoch: 060/150 | Train Time: 2.082s | Train Loss: 0.024181 |
# INFO:root:| Epoch: 061/150 | Train Time: 2.080s | Train Loss: 0.024133 |
# INFO:root:| Epoch: 062/150 | Train Time: 2.108s | Train Loss: 0.024239 |
# INFO:root:| Epoch: 063/150 | Train Time: 2.130s | Train Loss: 0.024266 |
# INFO:root:| Epoch: 064/150 | Train Time: 2.105s | Train Loss: 0.024187 |
# INFO:root:| Epoch: 065/150 | Train Time: 2.086s | Train Loss: 0.024104 |
# INFO:root:| Epoch: 066/150 | Train Time: 2.061s | Train Loss: 0.024266 |
# INFO:root:| Epoch: 067/150 | Train Time: 2.064s | Train Loss: 0.024210 |
# INFO:root:| Epoch: 068/150 | Train Time: 2.012s | Train Loss: 0.024134 |
# INFO:root:| Epoch: 069/150 | Train Time: 2.138s | Train Loss: 0.024167 |
# INFO:root:| Epoch: 070/150 | Train Time: 2.071s | Train Loss: 0.024094 |
# INFO:root:| Epoch: 071/150 | Train Time: 2.075s | Train Loss: 0.024224 |
# INFO:root:| Epoch: 072/150 | Train Time: 2.103s | Train Loss: 0.024136 |
# INFO:root:| Epoch: 073/150 | Train Time: 2.069s | Train Loss: 0.024213 |
# INFO:root:| Epoch: 074/150 | Train Time: 2.096s | Train Loss: 0.024068 |
# INFO:root:| Epoch: 075/150 | Train Time: 2.034s | Train Loss: 0.024110 |
# INFO:root:| Epoch: 076/150 | Train Time: 2.104s | Train Loss: 0.024012 |
# INFO:root:| Epoch: 077/150 | Train Time: 2.074s | Train Loss: 0.024086 |
# INFO:root:| Epoch: 078/150 | Train Time: 2.115s | Train Loss: 0.024138 |
# INFO:root:| Epoch: 079/150 | Train Time: 2.079s | Train Loss: 0.024160 |
# INFO:root:| Epoch: 080/150 | Train Time: 2.057s | Train Loss: 0.024080 |
# INFO:root:| Epoch: 081/150 | Train Time: 2.121s | Train Loss: 0.024094 |
# INFO:root:| Epoch: 082/150 | Train Time: 2.140s | Train Loss: 0.024156 |
# INFO:root:| Epoch: 083/150 | Train Time: 2.018s | Train Loss: 0.024061 |
# INFO:root:| Epoch: 084/150 | Train Time: 2.038s | Train Loss: 0.024153 |
# INFO:root:| Epoch: 085/150 | Train Time: 2.122s | Train Loss: 0.024123 |
# INFO:root:| Epoch: 086/150 | Train Time: 2.070s | Train Loss: 0.024111 |
# INFO:root:| Epoch: 087/150 | Train Time: 2.076s | Train Loss: 0.024020 |
# INFO:root:| Epoch: 088/150 | Train Time: 2.088s | Train Loss: 0.024026 |
# INFO:root:| Epoch: 089/150 | Train Time: 2.045s | Train Loss: 0.024042 |
# INFO:root:| Epoch: 090/150 | Train Time: 2.086s | Train Loss: 0.023980 |
# INFO:root:| Epoch: 091/150 | Train Time: 2.078s | Train Loss: 0.023906 |
# INFO:root:| Epoch: 092/150 | Train Time: 2.063s | Train Loss: 0.023938 |
# INFO:root:| Epoch: 093/150 | Train Time: 2.118s | Train Loss: 0.023982 |
# INFO:root:| Epoch: 094/150 | Train Time: 2.129s | Train Loss: 0.024035 |
# INFO:root:| Epoch: 095/150 | Train Time: 2.091s | Train Loss: 0.023878 |
# INFO:root:| Epoch: 096/150 | Train Time: 2.055s | Train Loss: 0.024041 |
# INFO:root:| Epoch: 097/150 | Train Time: 2.095s | Train Loss: 0.023948 |
# INFO:root:| Epoch: 098/150 | Train Time: 2.104s | Train Loss: 0.024017 |
# INFO:root:| Epoch: 099/150 | Train Time: 2.114s | Train Loss: 0.024062 |
# INFO:root:| Epoch: 100/150 | Train Time: 2.049s | Train Loss: 0.024059 |
# INFO:root:  LR scheduler: new learning rate is 1e-07
# INFO:root:| Epoch: 101/150 | Train Time: 2.090s | Train Loss: 0.023988 |
# INFO:root:| Epoch: 102/150 | Train Time: 2.150s | Train Loss: 0.023923 |
# INFO:root:| Epoch: 103/150 | Train Time: 2.090s | Train Loss: 0.024038 |
# INFO:root:| Epoch: 104/150 | Train Time: 2.121s | Train Loss: 0.024022 |
# INFO:root:| Epoch: 105/150 | Train Time: 2.052s | Train Loss: 0.024003 |
# INFO:root:| Epoch: 106/150 | Train Time: 2.135s | Train Loss: 0.023927 |
# INFO:root:| Epoch: 107/150 | Train Time: 2.133s | Train Loss: 0.023869 |
# INFO:root:| Epoch: 108/150 | Train Time: 2.072s | Train Loss: 0.023799 |
# INFO:root:| Epoch: 109/150 | Train Time: 2.099s | Train Loss: 0.023834 |
# INFO:root:| Epoch: 110/150 | Train Time: 2.083s | Train Loss: 0.023910 |
# INFO:root:| Epoch: 111/150 | Train Time: 2.071s | Train Loss: 0.024101 |
# INFO:root:| Epoch: 112/150 | Train Time: 2.079s | Train Loss: 0.023761 |
# INFO:root:| Epoch: 113/150 | Train Time: 2.125s | Train Loss: 0.023838 |
# INFO:root:| Epoch: 114/150 | Train Time: 2.104s | Train Loss: 0.023919 |
# INFO:root:| Epoch: 115/150 | Train Time: 2.089s | Train Loss: 0.023825 |
# INFO:root:| Epoch: 116/150 | Train Time: 2.127s | Train Loss: 0.023922 |
# INFO:root:| Epoch: 117/150 | Train Time: 2.205s | Train Loss: 0.023993 |
# INFO:root:| Epoch: 118/150 | Train Time: 2.098s | Train Loss: 0.024039 |
# INFO:root:| Epoch: 119/150 | Train Time: 2.143s | Train Loss: 0.023955 |
# INFO:root:| Epoch: 120/150 | Train Time: 2.157s | Train Loss: 0.023991 |
# INFO:root:| Epoch: 121/150 | Train Time: 2.065s | Train Loss: 0.024030 |
# INFO:root:| Epoch: 122/150 | Train Time: 2.100s | Train Loss: 0.023946 |
# INFO:root:| Epoch: 123/150 | Train Time: 2.097s | Train Loss: 0.024018 |
# INFO:root:| Epoch: 124/150 | Train Time: 2.029s | Train Loss: 0.023881 |
# INFO:root:| Epoch: 125/150 | Train Time: 2.064s | Train Loss: 0.023845 |
# INFO:root:| Epoch: 126/150 | Train Time: 2.142s | Train Loss: 0.023886 |
# INFO:root:| Epoch: 127/150 | Train Time: 2.093s | Train Loss: 0.023968 |
# INFO:root:| Epoch: 128/150 | Train Time: 2.102s | Train Loss: 0.024016 |
# INFO:root:| Epoch: 129/150 | Train Time: 2.113s | Train Loss: 0.023815 |
# INFO:root:| Epoch: 130/150 | Train Time: 2.264s | Train Loss: 0.023873 |
# INFO:root:| Epoch: 131/150 | Train Time: 2.124s | Train Loss: 0.024052 |
# INFO:root:| Epoch: 132/150 | Train Time: 2.234s | Train Loss: 0.023892 |
# INFO:root:| Epoch: 133/150 | Train Time: 2.075s | Train Loss: 0.023960 |
# INFO:root:| Epoch: 134/150 | Train Time: 2.153s | Train Loss: 0.023877 |
# INFO:root:| Epoch: 135/150 | Train Time: 2.111s | Train Loss: 0.024018 |
# INFO:root:| Epoch: 136/150 | Train Time: 2.133s | Train Loss: 0.023935 |
# INFO:root:| Epoch: 137/150 | Train Time: 2.095s | Train Loss: 0.023833 |
# INFO:root:| Epoch: 138/150 | Train Time: 2.105s | Train Loss: 0.023888 |
# INFO:root:| Epoch: 139/150 | Train Time: 2.058s | Train Loss: 0.023954 |
# INFO:root:| Epoch: 140/150 | Train Time: 2.078s | Train Loss: 0.023965 |
# INFO:root:| Epoch: 141/150 | Train Time: 2.059s | Train Loss: 0.024021 |
# INFO:root:| Epoch: 142/150 | Train Time: 2.087s | Train Loss: 0.023912 |
# INFO:root:| Epoch: 143/150 | Train Time: 2.072s | Train Loss: 0.024091 |
# INFO:root:| Epoch: 144/150 | Train Time: 2.095s | Train Loss: 0.023907 |
# INFO:root:| Epoch: 145/150 | Train Time: 2.097s | Train Loss: 0.023958 |
# INFO:root:| Epoch: 146/150 | Train Time: 2.079s | Train Loss: 0.024060 |
# INFO:root:| Epoch: 147/150 | Train Time: 2.062s | Train Loss: 0.023912 |
# INFO:root:| Epoch: 148/150 | Train Time: 2.126s | Train Loss: 0.023864 |
# INFO:root:| Epoch: 149/150 | Train Time: 2.077s | Train Loss: 0.023777 |
# INFO:root:| Epoch: 150/150 | Train Time: 2.108s | Train Loss: 0.023921 |
# INFO:root:Training Time: 316.325s
# INFO:root:Finished training.

# %%
model.test(dataset, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:Starting testing...
# INFO:root:Test AUC: 96.80%
# INFO:root:Test Time: 0.643s
# INFO:root:Finished testing.

# %%
model.save_model(export_model=model_path, save_ae=save_ae)

# %%
indices_, labels_, scores_ = zip(*model.results['test_scores'])
indices_, labels_, scores_ = np.array(indices_), np.array(labels_), np.array(scores_)
result_df = pd.DataFrame()
result_df['indices'] = indices_; result_df['labels'] = labels_; result_df['scores'] = scores_

result_df.drop('indices', inplace=True, axis=1)
df_normal = result_df[result_df.labels.isin(label_normal)]
df_abnormal = result_df[result_df.labels.isin(label_abnormal)]

cut_90 = df_normal.scores.quantile(0.90)
# np.save(cut_90_path, cut_90)

cut_95 = df_normal.scores.quantile(0.95)
# np.save(cut_95_path, cut_95)

cut_99 = df_normal.scores.quantile(0.99)
# np.save(cut_99_path, cut_99)

# %%
label_eval_list = [(i,) for i in range(10)]
total_roc_auc = []
total_recall_90 = []
total_recall_95 = []
total_recall_99 = []

for label_eval in label_eval_list:
    # Formating the path
    test_eval = False
    if (label_eval[0] in label_normal) or (label_eval[0] in label_abnormal):
        test_eval = True
        
    # Start evaluating
    dataset_eval = load_dataset(loader_name=loader_eval_name,
                                root=root,
                                label_eval=label_eval,
                                test_eval=test_eval)

    # Load model for evaluation
    if optimizer_ in ['one_class', 'one_class_unsupervised']:
        model_eval = OneClassModelEval(optimizer_, eta=eta)
    elif optimizer_ in ['rec', 'rec_unsupervised']:
        model_eval = RecModelEval(optimizer_, eta=eta)

    model_eval.set_network(net_name)
    model_eval.load_model(model_path=model_path, map_location=device)
    model_eval.test(dataset_eval,
                    eta=eta,
                    batch_size=batch_size,
                    device=device,
                    n_jobs_dataloader=n_jobs_dataloader,
                    label_normal=label_normal)
    _, labels, scores = zip(*model_eval.results['test_scores'])

    # Get predicted label
    y_90 = [1 if e > cut_90 else 0 for e in scores]
    y_95 = [1 if e > cut_95 else 0 for e in scores]
    y_99 = [1 if e > cut_99 else 0 for e in scores]

    if label_eval[0] in label_normal:
        print('Skip self!')
    else:
        # Record results when FP = 0.10
        recall_90 = sum(y_90) / len(y_90)
        total_recall_90.append(recall_90)
        msg = '[Recall for class {} (FP = 0.10)] {}\n'.format(label_eval[0], recall_90)
        print(msg)
        
        # Record results when FP = 0.05
        recall_95 = sum(y_95) / len(y_95)
        total_recall_95.append(recall_95)
        msg = '[Recall for class {} (FP = 0.05)] {}\n'.format(label_eval[0], recall_95)
        print(msg)
# Out:
# Starting evaluating...
# Test Loss: 0.024221
# Test Time: 0.248s
# Finished testing.
# Skip self!
# Starting evaluating...
# Test Loss: 2.057312
# Test Time: 2.012s
# Finished testing.
# [Recall for class 1 (FP = 0.10)] 0.6881428571428572
#
# [Recall for class 1 (FP = 0.05)] 0.4072857142857143
#
# Starting evaluating...
# Test Loss: 2.413994
# Test Time: 2.019s
# Finished testing.
# [Recall for class 2 (FP = 0.10)] 0.5335714285714286
#
# [Recall for class 2 (FP = 0.05)] 0.35942857142857143
#
# Starting evaluating...
# Test Loss: 3.010408
# Test Time: 1.968s
# Finished testing.
# [Recall for class 3 (FP = 0.10)] 0.34914285714285714
#
# [Recall for class 3 (FP = 0.05)] 0.14614285714285713
#
# Starting evaluating...
# Test Loss: 2.111366
# Test Time: 1.997s
# Finished testing.
# [Recall for class 4 (FP = 0.10)] 0.6655714285714286
#
# [Recall for class 4 (FP = 0.05)] 0.422
#
# Starting evaluating...
# Test Loss: 1.738416
# Test Time: 1.983s
# Finished testing.
# [Recall for class 5 (FP = 0.10)] 0.7698571428571429
#
# [Recall for class 5 (FP = 0.05)] 0.5544285714285714
#
# Starting evaluating...
# Test Loss: 3.676279
# Test Time: 1.984s
# Finished testing.
# [Recall for class 6 (FP = 0.10)] 0.2977142857142857
#
# [Recall for class 6 (FP = 0.05)] 0.15271428571428572
#
# Starting evaluating...
# Test Loss: 1.377557
# Test Time: 0.260s
# Finished testing.
# [Recall for class 7 (FP = 0.10)] 0.934
#
# [Recall for class 7 (FP = 0.05)] 0.832
#
# Starting evaluating...
# Test Loss: 1.382270
# Test Time: 2.024s
# Finished testing.
# [Recall for class 8 (FP = 0.10)] 0.91
#
# [Recall for class 8 (FP = 0.05)] 0.7667142857142857
#
# Starting evaluating...
# Test Loss: 0.921623
# Test Time: 2.009s
# Finished testing.
# [Recall for class 9 (FP = 0.10)] 0.995
#
# [Recall for class 9 (FP = 0.05)] 0.9762857142857143

# %% [markdown]
# Training results is good! Seems that even if the latent dimensions have been compressed to just 2, it can still do works.

# %% [markdown]
# # 3. Extract the Encoder Part

# %%
class RecEncoder:
    def __init__(self):

        self.net_name = None
        self.net = None
        self.ae_net = None


    def set_network(self, net_name: str='fmnist_LeNet_one_class'):
        """
        Set the network structure for the model.
        The key here is to initialize <self.net>.
        """
        self.net_name = net_name
        self.net = build_network(net_name)
        self.ae_net = build_network('fmnist_LeNet_rec')

    def load_model(self,
                   model_path,
                   map_location='cuda:1'):
        """
        Load the trained model for the model.
        The key here is to initialize <self.c>.
        """
        # Load the general model
        model_dict = torch.load(model_path, map_location=map_location)
        self.ae_net.load_state_dict(model_dict['net_dict'])
        
        # Obtain the net dictionary
        net_dict = self.net.state_dict()
        ae_net_dict = self.ae_net.state_dict()
        
        # Filter out decoder network keys
        ae_net_dict = {k: v for k, v in ae_net_dict.items() if k in net_dict}
        
        # Overwrite values in the existing state_dict
        net_dict.update(ae_net_dict)

        # Load the new state_dict
        self.net.load_state_dict(net_dict)
        

    def save_model(self, export_model, save_ae=True):
        net_dict = self.net.state_dict()
        torch.save({'net_dict': net_dict}, export_model)
    
    def test(self, dataset, device, batch_size, n_jobs_dataloader):
        all_loader = dataset.loaders(batch_size=batch_size,
                                     num_workers=n_jobs_dataloader)
        net = self.net.to(device)
        criterion = nn.MSELoss(reduction='none')
        
        n_batches = 0
        X_pred_list = []
        net.eval()
        
        with torch.no_grad():
            for data in all_loader:
                X, y, idx = data
                X, y, idx = X.to(device), y.to(device), idx.to(device)

                X_pred = net(X)
                X_pred_list += X_pred
        
        return np.array(X_pred_list)

# %%
encoder = RecEncoder()
encoder.set_network()
encoder.load_model(model_path, device)

# %%
label_eval_list = [(i,) for i in range(10)]
dataset_eval_list = []
for label_eval in label_eval_list:
    dataset_eval_list.append(load_dataset(loader_name=loader_eval_name,
                                          root=root,
                                          label_eval=label_eval,
                                          test_eval=False))

# %%
data_list = []
for dataset_eval in dataset_eval_list:
    data = encoder.test(dataset_eval, device, batch_size, n_jobs_dataloader)
    data = np.array([x.cpu().numpy() for x in data])
    data_list.append(data.T)

# %%
color_dict = {'tshirt':0,
              'shirt': 1,
              'dress':2,
              'pullover':3,
              'coat':4,
              'trouser':5,
               'bag': 6,
              'boot': 7,
              'sandal': 8,
              'sneaker':9}

num_to_letter ={0: 'tshirt', 
                1: 'trouser', 
                2: 'pullover', 
                3: 'dress', 
                4: 'coat',
                5: 'sandal', 
                6: 'shirt', 
                7: 'sneaker', 
                8: 'bag', 
                9: 'boot'}

letter_to_num = {v:k for k, v in num_to_letter.items()}

fig, ax = plt.subplots(figsize=(20, 10))

for letter in list(color_dict)[::-1]:
    label = letter_to_num[letter]
    data = data_list[label]
    cluster = sns.scatterplot(x=data[0], y=data[1], label=letter, alpha=0.2, color=sns.color_palette("hls", 12)[2:][color_dict[letter]])

plt.legend()
plt.title('Semi-supervised Reconstruction Model Using tshirt as Normal and sneaker as Abnormal (most different)')
plt.ylim(-0.04, 0.08)
plt.xlim(-0.04, 0.10)
sns.despine()
