# %%
import sys
sys.path.append('../dataset/')
sys.path.append('../network/')
sys.path.append('../model/')

import os
import glob
import time
import torch
import logging
import argparse
import numpy as np
import pandas as pd
import torch.optim as optim
import torch.nn as nn
import torch
import seaborn as sns

from pathlib import Path
from main_loading import *
from main_network import *
from main_model_rec import *
from main_model_one_class import *
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# > Modified things in local:
# - Changed the `network/main_network.py`, add a new term rep_dim and changed them all to 2.

# %% [markdown]
# # 0. Variable Definitions

# %%
label_dict ={0: 'tshirt', 
                1: 'trouser', 
                2: 'pullover', 
                3: 'dress', 
                4: 'coat',
                5: 'sandal', 
                6: 'shirt', 
                7: 'sneaker', 
                8: 'bag', 
                9: 'boot'}

# %%
# For data
root = '/net/leksai/data/FashionMNIST'
loader_name = 'fmnist'
loader_eval_name = 'fmnist_eval'
label_normal = (0,)
label_abnormal = (6,)
ratio_abnormal = 0

# For model
net_name = 'fmnist_LeNet_rec'
optimizer_ = 'rec'
eta = 0.1
optimizer_name = 'adam'
lr = 0.0001
ae_lr = 0.001
n_epochs = 150
ae_n_epochs = 150
lr_milestones = (50, 100, 150)
batch_size = 128
weight_decay = 0.5e-6
ae_weight_decay = 0.5e-3
device_no = 1
device = 'cuda:1'
n_jobs_dataloader = 0
save_ae = True
load_ae = False
log_path = 'misc/rec_fmnist_0_6.log'
model_path = 'misc/rec_fmnist_0_6.tar'

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler = logging.FileHandler(log_path)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %% [markdown]
# # 1. Load Dataset

# %%
dataset = load_dataset(loader_name=loader_name,
                       root=root,
                       label_normal=label_normal,
                       label_abnormal=label_abnormal,
                       ratio_abnormal=ratio_abnormal)
# Out:
# Loading dataset for you!
# Almost loaded!

# %% [markdown]
# # 2. Load Model

# %%
model = RecModel(optimizer_, eta)
model.set_network(net_name)

# %%
model.train(dataset, eta, optimizer_name, lr, n_epochs, lr_milestones,
            batch_size, weight_decay, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:Hey I am loading net for you!
# Learning rate: 0.0001
# INFO:root:Setting hyper-parameters!
# INFO:root:Starting training...
# INFO:root:| Epoch: 001/150 | Train Time: 1.117s | Train Loss: 0.155141 |
# INFO:root:| Epoch: 002/150 | Train Time: 1.011s | Train Loss: 0.072487 |
# INFO:root:| Epoch: 003/150 | Train Time: 1.026s | Train Loss: 0.050505 |
# INFO:root:| Epoch: 004/150 | Train Time: 1.113s | Train Loss: 0.042539 |
# INFO:root:| Epoch: 005/150 | Train Time: 1.027s | Train Loss: 0.039035 |
# INFO:root:| Epoch: 006/150 | Train Time: 1.042s | Train Loss: 0.035933 |
# INFO:root:| Epoch: 007/150 | Train Time: 1.059s | Train Loss: 0.034399 |
# INFO:root:| Epoch: 008/150 | Train Time: 1.089s | Train Loss: 0.032960 |
# INFO:root:| Epoch: 009/150 | Train Time: 1.079s | Train Loss: 0.032175 |
# INFO:root:| Epoch: 010/150 | Train Time: 1.141s | Train Loss: 0.031490 |
# INFO:root:| Epoch: 011/150 | Train Time: 1.081s | Train Loss: 0.030890 |
# INFO:root:| Epoch: 012/150 | Train Time: 1.069s | Train Loss: 0.030265 |
# INFO:root:| Epoch: 013/150 | Train Time: 1.191s | Train Loss: 0.029660 |
# INFO:root:| Epoch: 014/150 | Train Time: 1.059s | Train Loss: 0.029271 |
# INFO:root:| Epoch: 015/150 | Train Time: 1.053s | Train Loss: 0.028499 |
# INFO:root:| Epoch: 016/150 | Train Time: 1.019s | Train Loss: 0.028333 |
# INFO:root:| Epoch: 017/150 | Train Time: 1.075s | Train Loss: 0.028027 |
# INFO:root:| Epoch: 018/150 | Train Time: 0.990s | Train Loss: 0.027478 |
# INFO:root:| Epoch: 019/150 | Train Time: 1.081s | Train Loss: 0.027391 |
# INFO:root:| Epoch: 020/150 | Train Time: 1.063s | Train Loss: 0.027068 |
# INFO:root:| Epoch: 021/150 | Train Time: 1.077s | Train Loss: 0.027005 |
# INFO:root:| Epoch: 022/150 | Train Time: 1.066s | Train Loss: 0.026711 |
# INFO:root:| Epoch: 023/150 | Train Time: 1.048s | Train Loss: 0.026545 |
# INFO:root:| Epoch: 024/150 | Train Time: 0.994s | Train Loss: 0.026164 |
# INFO:root:| Epoch: 025/150 | Train Time: 1.050s | Train Loss: 0.026226 |
# INFO:root:| Epoch: 026/150 | Train Time: 1.171s | Train Loss: 0.025927 |
# INFO:root:| Epoch: 027/150 | Train Time: 1.057s | Train Loss: 0.026050 |
# INFO:root:| Epoch: 028/150 | Train Time: 1.003s | Train Loss: 0.025756 |
# INFO:root:| Epoch: 029/150 | Train Time: 1.028s | Train Loss: 0.025661 |
# INFO:root:| Epoch: 030/150 | Train Time: 1.054s | Train Loss: 0.025340 |
# INFO:root:| Epoch: 031/150 | Train Time: 1.057s | Train Loss: 0.025283 |
# INFO:root:| Epoch: 032/150 | Train Time: 1.016s | Train Loss: 0.025316 |
# INFO:root:| Epoch: 033/150 | Train Time: 1.062s | Train Loss: 0.025150 |
# INFO:root:| Epoch: 034/150 | Train Time: 0.972s | Train Loss: 0.025253 |
# INFO:root:| Epoch: 035/150 | Train Time: 1.061s | Train Loss: 0.024901 |
# INFO:root:| Epoch: 036/150 | Train Time: 1.005s | Train Loss: 0.024786 |
# INFO:root:| Epoch: 037/150 | Train Time: 1.025s | Train Loss: 0.024747 |
# INFO:root:| Epoch: 038/150 | Train Time: 1.084s | Train Loss: 0.024516 |
# INFO:root:| Epoch: 039/150 | Train Time: 1.015s | Train Loss: 0.024698 |
# INFO:root:| Epoch: 040/150 | Train Time: 0.997s | Train Loss: 0.024649 |
# INFO:root:| Epoch: 041/150 | Train Time: 1.017s | Train Loss: 0.024630 |
# INFO:root:| Epoch: 042/150 | Train Time: 1.036s | Train Loss: 0.024340 |
# INFO:root:| Epoch: 043/150 | Train Time: 1.044s | Train Loss: 0.024485 |
# INFO:root:| Epoch: 044/150 | Train Time: 1.075s | Train Loss: 0.024507 |
# INFO:root:| Epoch: 045/150 | Train Time: 1.053s | Train Loss: 0.024297 |
# INFO:root:| Epoch: 046/150 | Train Time: 1.018s | Train Loss: 0.024336 |
# INFO:root:| Epoch: 047/150 | Train Time: 1.021s | Train Loss: 0.024112 |
# INFO:root:| Epoch: 048/150 | Train Time: 0.988s | Train Loss: 0.024201 |
# INFO:root:| Epoch: 049/150 | Train Time: 1.134s | Train Loss: 0.024060 |
# INFO:root:| Epoch: 050/150 | Train Time: 1.007s | Train Loss: 0.023833 |
# INFO:root:  LR scheduler: new learning rate is 1e-06
# INFO:root:| Epoch: 051/150 | Train Time: 1.122s | Train Loss: 0.023906 |
# INFO:root:| Epoch: 052/150 | Train Time: 1.121s | Train Loss: 0.023736 |
# INFO:root:| Epoch: 053/150 | Train Time: 1.112s | Train Loss: 0.023701 |
# INFO:root:| Epoch: 054/150 | Train Time: 1.126s | Train Loss: 0.023858 |
# INFO:root:| Epoch: 055/150 | Train Time: 1.002s | Train Loss: 0.023814 |
# INFO:root:| Epoch: 056/150 | Train Time: 1.097s | Train Loss: 0.023662 |
# INFO:root:| Epoch: 057/150 | Train Time: 1.121s | Train Loss: 0.023796 |
# INFO:root:| Epoch: 058/150 | Train Time: 1.206s | Train Loss: 0.023640 |
# INFO:root:| Epoch: 059/150 | Train Time: 1.290s | Train Loss: 0.023688 |
# INFO:root:| Epoch: 060/150 | Train Time: 1.117s | Train Loss: 0.023797 |
# INFO:root:| Epoch: 061/150 | Train Time: 1.081s | Train Loss: 0.023780 |
# INFO:root:| Epoch: 062/150 | Train Time: 1.057s | Train Loss: 0.023678 |
# INFO:root:| Epoch: 063/150 | Train Time: 1.019s | Train Loss: 0.023788 |
# INFO:root:| Epoch: 064/150 | Train Time: 1.057s | Train Loss: 0.023696 |
# INFO:root:| Epoch: 065/150 | Train Time: 1.136s | Train Loss: 0.023651 |
# INFO:root:| Epoch: 066/150 | Train Time: 1.098s | Train Loss: 0.023737 |
# INFO:root:| Epoch: 067/150 | Train Time: 1.114s | Train Loss: 0.023797 |
# INFO:root:| Epoch: 068/150 | Train Time: 1.053s | Train Loss: 0.023659 |
# INFO:root:| Epoch: 069/150 | Train Time: 1.016s | Train Loss: 0.023567 |
# INFO:root:| Epoch: 070/150 | Train Time: 1.167s | Train Loss: 0.023536 |
# INFO:root:| Epoch: 071/150 | Train Time: 1.057s | Train Loss: 0.023785 |
# INFO:root:| Epoch: 072/150 | Train Time: 1.122s | Train Loss: 0.023547 |
# INFO:root:| Epoch: 073/150 | Train Time: 1.112s | Train Loss: 0.023558 |
# INFO:root:| Epoch: 074/150 | Train Time: 1.199s | Train Loss: 0.023614 |
# INFO:root:| Epoch: 075/150 | Train Time: 1.077s | Train Loss: 0.023701 |
# INFO:root:| Epoch: 076/150 | Train Time: 1.036s | Train Loss: 0.023617 |
# INFO:root:| Epoch: 077/150 | Train Time: 1.025s | Train Loss: 0.023497 |
# INFO:root:| Epoch: 078/150 | Train Time: 1.035s | Train Loss: 0.023487 |
# INFO:root:| Epoch: 079/150 | Train Time: 1.144s | Train Loss: 0.023528 |
# INFO:root:| Epoch: 080/150 | Train Time: 1.070s | Train Loss: 0.023696 |
# INFO:root:| Epoch: 081/150 | Train Time: 1.107s | Train Loss: 0.023551 |
# INFO:root:| Epoch: 082/150 | Train Time: 1.032s | Train Loss: 0.023518 |
# INFO:root:| Epoch: 083/150 | Train Time: 1.042s | Train Loss: 0.023574 |
# INFO:root:| Epoch: 084/150 | Train Time: 1.084s | Train Loss: 0.023578 |
# INFO:root:| Epoch: 085/150 | Train Time: 1.180s | Train Loss: 0.023604 |
# INFO:root:| Epoch: 086/150 | Train Time: 1.065s | Train Loss: 0.023611 |
# INFO:root:| Epoch: 087/150 | Train Time: 1.130s | Train Loss: 0.023708 |
# INFO:root:| Epoch: 088/150 | Train Time: 1.077s | Train Loss: 0.023639 |
# INFO:root:| Epoch: 089/150 | Train Time: 1.120s | Train Loss: 0.023735 |
# INFO:root:| Epoch: 090/150 | Train Time: 1.067s | Train Loss: 0.023616 |
# INFO:root:| Epoch: 091/150 | Train Time: 1.042s | Train Loss: 0.023537 |
# INFO:root:| Epoch: 092/150 | Train Time: 1.147s | Train Loss: 0.023467 |
# INFO:root:| Epoch: 093/150 | Train Time: 1.137s | Train Loss: 0.023556 |
# INFO:root:| Epoch: 094/150 | Train Time: 1.119s | Train Loss: 0.023532 |
# INFO:root:| Epoch: 095/150 | Train Time: 1.052s | Train Loss: 0.023547 |
# INFO:root:| Epoch: 096/150 | Train Time: 1.028s | Train Loss: 0.023406 |
# INFO:root:| Epoch: 097/150 | Train Time: 1.037s | Train Loss: 0.023513 |
# INFO:root:| Epoch: 098/150 | Train Time: 1.046s | Train Loss: 0.023463 |
# INFO:root:| Epoch: 099/150 | Train Time: 1.159s | Train Loss: 0.023512 |
# INFO:root:| Epoch: 100/150 | Train Time: 1.125s | Train Loss: 0.023488 |
# INFO:root:  LR scheduler: new learning rate is 1e-07
# INFO:root:| Epoch: 101/150 | Train Time: 1.140s | Train Loss: 0.023398 |
# INFO:root:| Epoch: 102/150 | Train Time: 1.052s | Train Loss: 0.023423 |
# INFO:root:| Epoch: 103/150 | Train Time: 1.067s | Train Loss: 0.023323 |
# INFO:root:| Epoch: 104/150 | Train Time: 1.160s | Train Loss: 0.023520 |
# INFO:root:| Epoch: 105/150 | Train Time: 1.102s | Train Loss: 0.023340 |
# INFO:root:| Epoch: 106/150 | Train Time: 1.068s | Train Loss: 0.023297 |
# INFO:root:| Epoch: 107/150 | Train Time: 1.029s | Train Loss: 0.023451 |
# INFO:root:| Epoch: 108/150 | Train Time: 1.150s | Train Loss: 0.023464 |
# INFO:root:| Epoch: 109/150 | Train Time: 1.093s | Train Loss: 0.023362 |
# INFO:root:| Epoch: 110/150 | Train Time: 1.047s | Train Loss: 0.023363 |
# INFO:root:| Epoch: 111/150 | Train Time: 1.138s | Train Loss: 0.023390 |
# INFO:root:| Epoch: 112/150 | Train Time: 1.041s | Train Loss: 0.023422 |
# INFO:root:| Epoch: 113/150 | Train Time: 1.107s | Train Loss: 0.023309 |
# INFO:root:| Epoch: 114/150 | Train Time: 1.080s | Train Loss: 0.023442 |
# INFO:root:| Epoch: 115/150 | Train Time: 1.125s | Train Loss: 0.023434 |
# INFO:root:| Epoch: 116/150 | Train Time: 1.105s | Train Loss: 0.023380 |
# INFO:root:| Epoch: 117/150 | Train Time: 1.043s | Train Loss: 0.023558 |
# INFO:root:| Epoch: 118/150 | Train Time: 0.998s | Train Loss: 0.023434 |
# INFO:root:| Epoch: 119/150 | Train Time: 1.035s | Train Loss: 0.023315 |
# INFO:root:| Epoch: 120/150 | Train Time: 1.089s | Train Loss: 0.023326 |
# INFO:root:| Epoch: 121/150 | Train Time: 1.104s | Train Loss: 0.023412 |
# INFO:root:| Epoch: 122/150 | Train Time: 1.118s | Train Loss: 0.023440 |
# INFO:root:| Epoch: 123/150 | Train Time: 1.112s | Train Loss: 0.023247 |
# INFO:root:| Epoch: 124/150 | Train Time: 1.106s | Train Loss: 0.023473 |
# INFO:root:| Epoch: 125/150 | Train Time: 1.197s | Train Loss: 0.023409 |
# INFO:root:| Epoch: 126/150 | Train Time: 1.120s | Train Loss: 0.023367 |
# INFO:root:| Epoch: 127/150 | Train Time: 1.072s | Train Loss: 0.023286 |
# INFO:root:| Epoch: 128/150 | Train Time: 1.001s | Train Loss: 0.023501 |
# INFO:root:| Epoch: 129/150 | Train Time: 1.042s | Train Loss: 0.023421 |
# INFO:root:| Epoch: 130/150 | Train Time: 1.085s | Train Loss: 0.023341 |
# INFO:root:| Epoch: 131/150 | Train Time: 1.081s | Train Loss: 0.023416 |
# INFO:root:| Epoch: 132/150 | Train Time: 1.134s | Train Loss: 0.023409 |
# INFO:root:| Epoch: 133/150 | Train Time: 1.067s | Train Loss: 0.023465 |
# INFO:root:| Epoch: 134/150 | Train Time: 1.012s | Train Loss: 0.023413 |
# INFO:root:| Epoch: 135/150 | Train Time: 1.039s | Train Loss: 0.023428 |
# INFO:root:| Epoch: 136/150 | Train Time: 1.110s | Train Loss: 0.023351 |
# INFO:root:| Epoch: 137/150 | Train Time: 1.071s | Train Loss: 0.023425 |
# INFO:root:| Epoch: 138/150 | Train Time: 1.073s | Train Loss: 0.023473 |
# INFO:root:| Epoch: 139/150 | Train Time: 1.195s | Train Loss: 0.023395 |
# INFO:root:| Epoch: 140/150 | Train Time: 1.083s | Train Loss: 0.023392 |
# INFO:root:| Epoch: 141/150 | Train Time: 1.052s | Train Loss: 0.023527 |
# INFO:root:| Epoch: 142/150 | Train Time: 1.052s | Train Loss: 0.023284 |
# INFO:root:| Epoch: 143/150 | Train Time: 1.080s | Train Loss: 0.023288 |
# INFO:root:| Epoch: 144/150 | Train Time: 1.051s | Train Loss: 0.023394 |
# INFO:root:| Epoch: 145/150 | Train Time: 1.074s | Train Loss: 0.023290 |
# INFO:root:| Epoch: 146/150 | Train Time: 1.108s | Train Loss: 0.023405 |
# INFO:root:| Epoch: 147/150 | Train Time: 1.115s | Train Loss: 0.023260 |
# INFO:root:| Epoch: 148/150 | Train Time: 1.105s | Train Loss: 0.023249 |
# INFO:root:| Epoch: 149/150 | Train Time: 1.074s | Train Loss: 0.023492 |
# INFO:root:| Epoch: 150/150 | Train Time: 0.992s | Train Loss: 0.023165 |
# INFO:root:Training Time: 161.751s
# INFO:root:Finished training.

# %%
model.test(dataset, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:Starting testing...
# INFO:root:Test AUC: 74.10%
# INFO:root:Test Time: 0.388s
# INFO:root:Finished testing.

# %%
model.save_model(export_model=model_path, save_ae=save_ae)

# %%
indices_, labels_, scores_ = zip(*model.results['test_scores'])
indices_, labels_, scores_ = np.array(indices_), np.array(labels_), np.array(scores_)
result_df = pd.DataFrame()
result_df['indices'] = indices_; result_df['labels'] = labels_; result_df['scores'] = scores_

result_df.drop('indices', inplace=True, axis=1)
df_normal = result_df[result_df.labels.isin(label_normal)]
df_abnormal = result_df[result_df.labels.isin(label_abnormal)]

cut_90 = df_normal.scores.quantile(0.90)
# np.save(cut_90_path, cut_90)

cut_95 = df_normal.scores.quantile(0.95)
# np.save(cut_95_path, cut_95)

cut_99 = df_normal.scores.quantile(0.99)
# np.save(cut_99_path, cut_99)

# %%
label_eval_list = [(i,) for i in range(10)]
total_roc_auc = []
total_recall_90 = []
total_recall_95 = []
total_recall_99 = []

for label_eval in label_eval_list:
    # Formating the path
    test_eval = False
    if (label_eval[0] in label_normal) or (label_eval[0] in label_abnormal):
        test_eval = True
        
    # Start evaluating
    dataset_eval = load_dataset(loader_name=loader_eval_name,
                                root=root,
                                label_eval=label_eval,
                                test_eval=test_eval)

    # Load model for evaluation
    if optimizer_ in ['one_class', 'one_class_unsupervised']:
        model_eval = OneClassModelEval(optimizer_, eta=eta)
    elif optimizer_ in ['rec', 'rec_unsupervised']:
        model_eval = RecModelEval(optimizer_, eta=eta)

    model_eval.set_network(net_name)
    model_eval.load_model(model_path=model_path, map_location=device)
    model_eval.test(dataset_eval,
                    eta=eta,
                    batch_size=batch_size,
                    device=device,
                    n_jobs_dataloader=n_jobs_dataloader,
                    label_normal=label_normal)
    _, labels, scores = zip(*model_eval.results['test_scores'])

    # Get predicted label
    y_90 = [1 if e > cut_90 else 0 for e in scores]
    y_95 = [1 if e > cut_95 else 0 for e in scores]
    y_99 = [1 if e > cut_99 else 0 for e in scores]

    if label_eval[0] in label_normal:
        print('Skip self!')
    else:
        # Record results when FP = 0.10
        recall_90 = sum(y_90) / len(y_90)
        total_recall_90.append(recall_90)
        msg = '[Recall for class {} (FP = 0.10)] {}\n'.format(label_eval[0], recall_90)
        print(msg)
        
        # Record results when FP = 0.05
        recall_95 = sum(y_95) / len(y_95)
        total_recall_95.append(recall_95)
        msg = '[Recall for class {} (FP = 0.05)] {}\n'.format(label_eval[0], recall_95)
        print(msg)
# Out:
# Starting evaluating...
# Test Loss: 0.024623
# Test Time: 0.150s
# Finished testing.
# Skip self!
# Starting evaluating...
# Test Loss: 2.125300
# Test Time: 1.028s
# Finished testing.
# [Recall for class 1 (FP = 0.10)] 0.6208571428571429
#
# [Recall for class 1 (FP = 0.05)] 0.30757142857142855
#
# Starting evaluating...
# Test Loss: 2.307092
# Test Time: 0.883s
# Finished testing.
# [Recall for class 2 (FP = 0.10)] 0.5694285714285714
#
# [Recall for class 2 (FP = 0.05)] 0.40714285714285714
#
# Starting evaluating...
# Test Loss: 2.996416
# Test Time: 0.947s
# Finished testing.
# [Recall for class 3 (FP = 0.10)] 0.3142857142857143
#
# [Recall for class 3 (FP = 0.05)] 0.12471428571428571
#
# Starting evaluating...
# Test Loss: 1.828091
# Test Time: 0.955s
# Finished testing.
# [Recall for class 4 (FP = 0.10)] 0.7511428571428571
#
# [Recall for class 4 (FP = 0.05)] 0.5625714285714286
#
# Starting evaluating...
# Test Loss: 1.870904
# Test Time: 1.020s
# Finished testing.
# [Recall for class 5 (FP = 0.10)] 0.6784285714285714
#
# [Recall for class 5 (FP = 0.05)] 0.4412857142857143
#
# Starting evaluating...
# Test Loss: 3.511863
# Test Time: 0.155s
# Finished testing.
# [Recall for class 6 (FP = 0.10)] 0.359
#
# [Recall for class 6 (FP = 0.05)] 0.217
#
# Starting evaluating...
# Test Loss: 1.526964
# Test Time: 1.031s
# Finished testing.
# [Recall for class 7 (FP = 0.10)] 0.8755714285714286
#
# [Recall for class 7 (FP = 0.05)] 0.7082857142857143
#
# Starting evaluating...
# Test Loss: 1.529386
# Test Time: 0.926s
# Finished testing.
# [Recall for class 8 (FP = 0.10)] 0.8575714285714285
#
# [Recall for class 8 (FP = 0.05)] 0.6352857142857142
#
# Starting evaluating...
# Test Loss: 0.980662
# Test Time: 0.952s
# Finished testing.
# [Recall for class 9 (FP = 0.10)] 0.9898571428571429
#
# [Recall for class 9 (FP = 0.05)] 0.9505714285714286

# %% [markdown]
# Training results is good! Seems that even if the latent dimensions have been compressed to just 2, it can still do works.

# %% [markdown]
# # 3. Extract the Encoder Part

# %%
class RecEncoder:
    def __init__(self):

        self.net_name = None
        self.net = None
        self.ae_net = None


    def set_network(self, net_name: str='fmnist_LeNet_one_class'):
        """
        Set the network structure for the model.
        The key here is to initialize <self.net>.
        """
        self.net_name = net_name
        self.net = build_network(net_name)
        self.ae_net = build_network('fmnist_LeNet_rec')

    def load_model(self,
                   model_path,
                   map_location='cuda:1'):
        """
        Load the trained model for the model.
        The key here is to initialize <self.c>.
        """
        # Load the general model
        model_dict = torch.load(model_path, map_location=map_location)
        self.ae_net.load_state_dict(model_dict['net_dict'])
        
        # Obtain the net dictionary
        net_dict = self.net.state_dict()
        ae_net_dict = self.ae_net.state_dict()
        
        # Filter out decoder network keys
        ae_net_dict = {k: v for k, v in ae_net_dict.items() if k in net_dict}
        
        # Overwrite values in the existing state_dict
        net_dict.update(ae_net_dict)

        # Load the new state_dict
        self.net.load_state_dict(net_dict)
        

    def save_model(self, export_model, save_ae=True):
        net_dict = self.net.state_dict()
        torch.save({'net_dict': net_dict}, export_model)
    
    def test(self, dataset, device, batch_size, n_jobs_dataloader):
        all_loader = dataset.loaders(batch_size=batch_size,
                                     num_workers=n_jobs_dataloader)
        net = self.net.to(device)
        criterion = nn.MSELoss(reduction='none')
        
        n_batches = 0
        X_pred_list = []
        net.eval()
        
        with torch.no_grad():
            for data in all_loader:
                X, y, idx = data
                X, y, idx = X.to(device), y.to(device), idx.to(device)

                X_pred = net(X)
                X_pred_list += X_pred
        
        return np.array(X_pred_list)

# %%
encoder = RecEncoder()
encoder.set_network()
encoder.load_model(model_path, device)

# %%
label_eval_list = [(i,) for i in range(10)]
dataset_eval_list = []
for label_eval in label_eval_list:
    dataset_eval_list.append(load_dataset(loader_name=loader_eval_name,
                                          root=root,
                                          label_eval=label_eval,
                                          test_eval=False))

# %%
data_list = []
for dataset_eval in dataset_eval_list:
    data = encoder.test(dataset_eval, device, batch_size, n_jobs_dataloader)
    data = np.array([x.cpu().numpy() for x in data])
    data_list.append(data.T)

# %%
color_dict = {'tshirt':0,
              'shirt': 1,
              'dress':2,
              'pullover':3,
              'coat':4,
              'trouser':5,
               'bag': 6,
              'boot': 7,
              'sandal': 8,
              'sneaker':9}

num_to_letter ={0: 'tshirt', 
                1: 'trouser', 
                2: 'pullover', 
                3: 'dress', 
                4: 'coat',
                5: 'sandal', 
                6: 'shirt', 
                7: 'sneaker', 
                8: 'bag', 
                9: 'boot'}

letter_to_num = {v:k for k, v in num_to_letter.items()}

fig, ax = plt.subplots(figsize=(20, 10))

for letter in list(color_dict)[::-1]:
    label = letter_to_num[letter]
    data = data_list[label]
    cluster = sns.scatterplot(x=data[0], y=data[1], label=letter, alpha=0.2, color=sns.color_palette("hls", 12)[2:][color_dict[letter]])

plt.legend()
plt.title('Semi-supervised Reconstruction Model Using tshirt as Normal and shirt as Abnormal (most similar)')
plt.ylim(-0.04, 0.08)
plt.xlim(-0.04, 0.10)
sns.despine()

# %%
list(color_dict)[::-1]
# Out:
# ['sneaker',
#  'sandal',
#  'boot',
#  'bag',
#  'trouser',
#  'coat',
#  'pullover',
#  'dress',
#  'shirt',
#  'tshirt']

# %%
k[::-1]
# Out:
# [4, 2, 1]

# %%
fig, ax = plt.subplots(figsize=(20, 10))

for i, data in enumerate(data_list):
    cluster = sns.scatterplot(x=data[0], y=data[1], label=label_dict[i], alpha=0.2, color=sns.color_palette("hls", 10)[i])

plt.legend()
plt.title('Semi-supervised Reconstruction Model Using tshirt as Normal and shirt as Abnormal (most similar)')
plt.ylim(-0.04, 0.08)
plt.xlim(-0.04, 0.10)
sns.despine()
