# %%
import sys
sys.path.append('../dataset/')
sys.path.append('../network/')
sys.path.append('../model/')

import os
import glob
import time
import torch
import logging
import argparse
import numpy as np
import pandas as pd
import torch.optim as optim
import torch.nn as nn
import torch
import seaborn as sns

from pathlib import Path
from main_loading import *
from main_network import *
from main_model_rec import *
from main_model_one_class import *
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# > Modified things in local:
# - Changed the `network/main_network.py`, add a new term rep_dim and changed them all to 2.

# %% [markdown]
# # 0. Variable Definitions

# %%
# For data
root = '/net/leksai/data/FashionMNIST'
loader_name = 'fmnist'
loader_eval_name = 'fmnist_eval'
label_normal = (0,)
label_abnormal = (7,)
ratio_abnormal = 0

# For model
pretrain = True
net_name = 'fmnist_LeNet_one_class'
optimizer_ = 'one_class'
eta = 0.1
optimizer_name = 'adam'
lr = 0.0001
ae_lr = 0.001
n_epochs = 150
ae_n_epochs = 150
lr_milestones = (50, 100, 150)
batch_size = 128
weight_decay = 0.5e-6
ae_weight_decay = 0.5e-3
device_no = 2
device = 'cuda:0'
n_jobs_dataloader = 0
save_ae = True
load_ae = False

log_path = 'misc/one_class_fmnist_0_7.log'
model_path = 'misc/one_class_fmnist_0_7.tar'

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler = logging.FileHandler(log_path)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %% [markdown]
# # 1. Load Dataset

# %%
dataset = load_dataset(loader_name=loader_name,
                       root=root,
                       label_normal=label_normal,
                       label_abnormal=label_abnormal,
                       ratio_abnormal=ratio_abnormal)
# Out:
# Loading dataset for you!
# Almost loaded!

# %% [markdown]
# # 2. Load Model

# %%
model = OneClassModel(optimizer_, eta)
model.set_network(net_name)
logger.info('I am pre-training for you.')
model.pretrain(dataset, optimizer_name, ae_lr, ae_n_epochs, lr_milestones,
               batch_size, ae_weight_decay, device, n_jobs_dataloader)
model.train(dataset, eta, optimizer_name, lr, n_epochs, lr_milestones,
            batch_size, weight_decay, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:I am pre-training for you.
# /home/ziyuye/env/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# INFO:root:| Epoch: 001/150 | Train Time: 1.138s | Train Loss: 0.051236 |
# INFO:root:| Epoch: 002/150 | Train Time: 1.071s | Train Loss: 0.028389 |
# INFO:root:| Epoch: 003/150 | Train Time: 1.092s | Train Loss: 0.026992 |
# INFO:root:| Epoch: 004/150 | Train Time: 1.049s | Train Loss: 0.026204 |
# INFO:root:| Epoch: 005/150 | Train Time: 1.082s | Train Loss: 0.025856 |
# INFO:root:| Epoch: 006/150 | Train Time: 1.103s | Train Loss: 0.025640 |
# INFO:root:| Epoch: 007/150 | Train Time: 1.078s | Train Loss: 0.025640 |
# INFO:root:| Epoch: 008/150 | Train Time: 1.032s | Train Loss: 0.025504 |
# INFO:root:| Epoch: 009/150 | Train Time: 1.078s | Train Loss: 0.025027 |
# INFO:root:| Epoch: 010/150 | Train Time: 1.062s | Train Loss: 0.025199 |
# INFO:root:| Epoch: 011/150 | Train Time: 1.085s | Train Loss: 0.025050 |
# INFO:root:| Epoch: 012/150 | Train Time: 1.003s | Train Loss: 0.024871 |
# INFO:root:| Epoch: 013/150 | Train Time: 1.017s | Train Loss: 0.024632 |
# INFO:root:| Epoch: 014/150 | Train Time: 1.116s | Train Loss: 0.024876 |
# INFO:root:| Epoch: 015/150 | Train Time: 1.083s | Train Loss: 0.024589 |
# INFO:root:| Epoch: 016/150 | Train Time: 1.077s | Train Loss: 0.024673 |
# INFO:root:| Epoch: 017/150 | Train Time: 1.131s | Train Loss: 0.024517 |
# INFO:root:| Epoch: 018/150 | Train Time: 1.098s | Train Loss: 0.024654 |
# INFO:root:| Epoch: 019/150 | Train Time: 1.096s | Train Loss: 0.024582 |
# INFO:root:| Epoch: 020/150 | Train Time: 1.078s | Train Loss: 0.024580 |
# INFO:root:| Epoch: 021/150 | Train Time: 1.048s | Train Loss: 0.024535 |
# INFO:root:| Epoch: 022/150 | Train Time: 1.064s | Train Loss: 0.024562 |
# INFO:root:| Epoch: 023/150 | Train Time: 1.057s | Train Loss: 0.024485 |
# INFO:root:| Epoch: 024/150 | Train Time: 1.064s | Train Loss: 0.024373 |
# INFO:root:| Epoch: 025/150 | Train Time: 1.093s | Train Loss: 0.024429 |
# INFO:root:| Epoch: 026/150 | Train Time: 1.039s | Train Loss: 0.024342 |
# INFO:root:| Epoch: 027/150 | Train Time: 1.027s | Train Loss: 0.024338 |
# INFO:root:| Epoch: 028/150 | Train Time: 1.071s | Train Loss: 0.024316 |
# INFO:root:| Epoch: 029/150 | Train Time: 1.022s | Train Loss: 0.024507 |
# INFO:root:| Epoch: 030/150 | Train Time: 1.032s | Train Loss: 0.024206 |
# INFO:root:| Epoch: 031/150 | Train Time: 1.075s | Train Loss: 0.024120 |
# INFO:root:| Epoch: 032/150 | Train Time: 1.043s | Train Loss: 0.024526 |
# INFO:root:| Epoch: 033/150 | Train Time: 1.033s | Train Loss: 0.024459 |
# INFO:root:| Epoch: 034/150 | Train Time: 1.116s | Train Loss: 0.024319 |
# INFO:root:| Epoch: 035/150 | Train Time: 1.070s | Train Loss: 0.024279 |
# INFO:root:| Epoch: 036/150 | Train Time: 1.085s | Train Loss: 0.024343 |
# INFO:root:| Epoch: 037/150 | Train Time: 1.071s | Train Loss: 0.024257 |
# INFO:root:| Epoch: 038/150 | Train Time: 1.031s | Train Loss: 0.024204 |
# INFO:root:| Epoch: 039/150 | Train Time: 1.045s | Train Loss: 0.024332 |
# INFO:root:| Epoch: 040/150 | Train Time: 1.091s | Train Loss: 0.024065 |
# INFO:root:| Epoch: 041/150 | Train Time: 1.055s | Train Loss: 0.024452 |
# INFO:root:| Epoch: 042/150 | Train Time: 1.042s | Train Loss: 0.024124 |
# INFO:root:| Epoch: 043/150 | Train Time: 1.084s | Train Loss: 0.024107 |
# INFO:root:| Epoch: 044/150 | Train Time: 1.014s | Train Loss: 0.024432 |
# INFO:root:| Epoch: 045/150 | Train Time: 1.078s | Train Loss: 0.024154 |
# INFO:root:| Epoch: 046/150 | Train Time: 1.070s | Train Loss: 0.023886 |
# INFO:root:| Epoch: 047/150 | Train Time: 1.077s | Train Loss: 0.023878 |
# INFO:root:| Epoch: 048/150 | Train Time: 0.956s | Train Loss: 0.024013 |
# INFO:root:| Epoch: 049/150 | Train Time: 1.032s | Train Loss: 0.024090 |
# INFO:root:| Epoch: 050/150 | Train Time: 1.019s | Train Loss: 0.023293 |
# INFO:root:  LR scheduler: new learning rate is 0.0001
# INFO:root:| Epoch: 051/150 | Train Time: 1.048s | Train Loss: 0.023031 |
# INFO:root:| Epoch: 052/150 | Train Time: 1.054s | Train Loss: 0.022933 |
# INFO:root:| Epoch: 053/150 | Train Time: 1.066s | Train Loss: 0.022866 |
# INFO:root:| Epoch: 054/150 | Train Time: 1.075s | Train Loss: 0.022764 |
# INFO:root:| Epoch: 055/150 | Train Time: 1.025s | Train Loss: 0.022722 |
# INFO:root:| Epoch: 056/150 | Train Time: 1.012s | Train Loss: 0.022680 |
# INFO:root:| Epoch: 057/150 | Train Time: 1.085s | Train Loss: 0.022655 |
# INFO:root:| Epoch: 058/150 | Train Time: 1.094s | Train Loss: 0.022736 |
# INFO:root:| Epoch: 059/150 | Train Time: 1.037s | Train Loss: 0.022642 |
# INFO:root:| Epoch: 060/150 | Train Time: 1.029s | Train Loss: 0.022511 |
# INFO:root:| Epoch: 061/150 | Train Time: 1.046s | Train Loss: 0.022464 |
# INFO:root:| Epoch: 062/150 | Train Time: 1.020s | Train Loss: 0.022505 |
# INFO:root:| Epoch: 063/150 | Train Time: 1.048s | Train Loss: 0.022631 |
# INFO:root:| Epoch: 064/150 | Train Time: 1.067s | Train Loss: 0.022594 |
# INFO:root:| Epoch: 065/150 | Train Time: 1.025s | Train Loss: 0.022461 |
# INFO:root:| Epoch: 066/150 | Train Time: 1.084s | Train Loss: 0.022456 |
# INFO:root:| Epoch: 067/150 | Train Time: 1.057s | Train Loss: 0.022601 |
# INFO:root:| Epoch: 068/150 | Train Time: 1.036s | Train Loss: 0.022502 |
# INFO:root:| Epoch: 069/150 | Train Time: 1.042s | Train Loss: 0.022460 |
# INFO:root:| Epoch: 070/150 | Train Time: 1.009s | Train Loss: 0.022485 |
# INFO:root:| Epoch: 071/150 | Train Time: 1.044s | Train Loss: 0.022359 |
# INFO:root:| Epoch: 072/150 | Train Time: 1.049s | Train Loss: 0.022348 |
# INFO:root:| Epoch: 073/150 | Train Time: 1.071s | Train Loss: 0.022410 |
# INFO:root:| Epoch: 074/150 | Train Time: 1.026s | Train Loss: 0.022386 |
# INFO:root:| Epoch: 075/150 | Train Time: 1.048s | Train Loss: 0.022495 |
# INFO:root:| Epoch: 076/150 | Train Time: 1.033s | Train Loss: 0.022354 |
# INFO:root:| Epoch: 077/150 | Train Time: 1.116s | Train Loss: 0.022471 |
# INFO:root:| Epoch: 078/150 | Train Time: 1.104s | Train Loss: 0.022281 |
# INFO:root:| Epoch: 079/150 | Train Time: 1.089s | Train Loss: 0.022275 |
# INFO:root:| Epoch: 080/150 | Train Time: 1.092s | Train Loss: 0.022110 |
# INFO:root:| Epoch: 081/150 | Train Time: 1.076s | Train Loss: 0.022323 |
# INFO:root:| Epoch: 082/150 | Train Time: 1.069s | Train Loss: 0.022377 |
# INFO:root:| Epoch: 083/150 | Train Time: 1.076s | Train Loss: 0.022233 |
# INFO:root:| Epoch: 084/150 | Train Time: 1.099s | Train Loss: 0.022141 |
# INFO:root:| Epoch: 085/150 | Train Time: 1.047s | Train Loss: 0.022241 |
# INFO:root:| Epoch: 086/150 | Train Time: 1.020s | Train Loss: 0.022250 |
# INFO:root:| Epoch: 087/150 | Train Time: 1.023s | Train Loss: 0.022243 |
# INFO:root:| Epoch: 088/150 | Train Time: 1.044s | Train Loss: 0.022242 |
# INFO:root:| Epoch: 089/150 | Train Time: 1.006s | Train Loss: 0.022026 |
# INFO:root:| Epoch: 090/150 | Train Time: 1.004s | Train Loss: 0.022109 |
# INFO:root:| Epoch: 091/150 | Train Time: 0.983s | Train Loss: 0.022142 |
# INFO:root:| Epoch: 092/150 | Train Time: 1.009s | Train Loss: 0.022149 |
# INFO:root:| Epoch: 093/150 | Train Time: 1.054s | Train Loss: 0.022103 |
# INFO:root:| Epoch: 094/150 | Train Time: 1.084s | Train Loss: 0.022021 |
# INFO:root:| Epoch: 095/150 | Train Time: 1.068s | Train Loss: 0.022331 |
# INFO:root:| Epoch: 096/150 | Train Time: 1.066s | Train Loss: 0.022061 |
# INFO:root:| Epoch: 097/150 | Train Time: 1.026s | Train Loss: 0.022194 |
# INFO:root:| Epoch: 098/150 | Train Time: 1.100s | Train Loss: 0.022193 |
# INFO:root:| Epoch: 099/150 | Train Time: 1.064s | Train Loss: 0.021925 |
# INFO:root:| Epoch: 100/150 | Train Time: 1.055s | Train Loss: 0.021760 |
# INFO:root:  LR scheduler: new learning rate is 1e-05
# INFO:root:| Epoch: 101/150 | Train Time: 1.011s | Train Loss: 0.021679 |
# INFO:root:| Epoch: 102/150 | Train Time: 1.009s | Train Loss: 0.021562 |
# INFO:root:| Epoch: 103/150 | Train Time: 0.985s | Train Loss: 0.021628 |
# INFO:root:| Epoch: 104/150 | Train Time: 1.068s | Train Loss: 0.021658 |
# INFO:root:| Epoch: 105/150 | Train Time: 1.103s | Train Loss: 0.021616 |
# INFO:root:| Epoch: 106/150 | Train Time: 1.026s | Train Loss: 0.021520 |
# INFO:root:| Epoch: 107/150 | Train Time: 0.969s | Train Loss: 0.021601 |
# INFO:root:| Epoch: 108/150 | Train Time: 1.110s | Train Loss: 0.021577 |
# INFO:root:| Epoch: 109/150 | Train Time: 1.063s | Train Loss: 0.021541 |
# INFO:root:| Epoch: 110/150 | Train Time: 1.058s | Train Loss: 0.021636 |
# INFO:root:| Epoch: 111/150 | Train Time: 1.090s | Train Loss: 0.021677 |
# INFO:root:| Epoch: 112/150 | Train Time: 1.044s | Train Loss: 0.021538 |
# INFO:root:| Epoch: 113/150 | Train Time: 1.048s | Train Loss: 0.021560 |
# INFO:root:| Epoch: 114/150 | Train Time: 1.059s | Train Loss: 0.021561 |
# INFO:root:| Epoch: 115/150 | Train Time: 1.039s | Train Loss: 0.021427 |
# INFO:root:| Epoch: 116/150 | Train Time: 1.107s | Train Loss: 0.021526 |
# INFO:root:| Epoch: 117/150 | Train Time: 1.049s | Train Loss: 0.021488 |
# INFO:root:| Epoch: 118/150 | Train Time: 1.024s | Train Loss: 0.021547 |
# INFO:root:| Epoch: 119/150 | Train Time: 1.071s | Train Loss: 0.021557 |
# INFO:root:| Epoch: 120/150 | Train Time: 1.056s | Train Loss: 0.021595 |
# INFO:root:| Epoch: 121/150 | Train Time: 1.044s | Train Loss: 0.021566 |
# INFO:root:| Epoch: 122/150 | Train Time: 1.065s | Train Loss: 0.021429 |
# INFO:root:| Epoch: 123/150 | Train Time: 1.083s | Train Loss: 0.021567 |
# INFO:root:| Epoch: 124/150 | Train Time: 1.030s | Train Loss: 0.021487 |
# INFO:root:| Epoch: 125/150 | Train Time: 1.094s | Train Loss: 0.021582 |
# INFO:root:| Epoch: 126/150 | Train Time: 1.143s | Train Loss: 0.021424 |
# INFO:root:| Epoch: 127/150 | Train Time: 1.018s | Train Loss: 0.021549 |
# INFO:root:| Epoch: 128/150 | Train Time: 0.985s | Train Loss: 0.021533 |
# INFO:root:| Epoch: 129/150 | Train Time: 1.087s | Train Loss: 0.021561 |
# INFO:root:| Epoch: 130/150 | Train Time: 1.062s | Train Loss: 0.021480 |
# INFO:root:| Epoch: 131/150 | Train Time: 1.059s | Train Loss: 0.021484 |
# INFO:root:| Epoch: 132/150 | Train Time: 1.072s | Train Loss: 0.021393 |
# INFO:root:| Epoch: 133/150 | Train Time: 1.031s | Train Loss: 0.021513 |
# INFO:root:| Epoch: 134/150 | Train Time: 1.043s | Train Loss: 0.021516 |
# INFO:root:| Epoch: 135/150 | Train Time: 1.039s | Train Loss: 0.021468 |
# INFO:root:| Epoch: 136/150 | Train Time: 1.067s | Train Loss: 0.021401 |
# INFO:root:| Epoch: 137/150 | Train Time: 1.006s | Train Loss: 0.021480 |
# INFO:root:| Epoch: 138/150 | Train Time: 1.044s | Train Loss: 0.021469 |
# INFO:root:| Epoch: 139/150 | Train Time: 1.043s | Train Loss: 0.021532 |
# INFO:root:| Epoch: 140/150 | Train Time: 1.072s | Train Loss: 0.021464 |
# INFO:root:| Epoch: 141/150 | Train Time: 1.074s | Train Loss: 0.021482 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.991s | Train Loss: 0.021383 |
# INFO:root:| Epoch: 143/150 | Train Time: 1.039s | Train Loss: 0.021459 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.979s | Train Loss: 0.021345 |
# INFO:root:| Epoch: 145/150 | Train Time: 1.071s | Train Loss: 0.021557 |
# INFO:root:| Epoch: 146/150 | Train Time: 1.043s | Train Loss: 0.021483 |
# INFO:root:| Epoch: 147/150 | Train Time: 1.054s | Train Loss: 0.021414 |
# INFO:root:| Epoch: 148/150 | Train Time: 1.030s | Train Loss: 0.021535 |
# INFO:root:| Epoch: 149/150 | Train Time: 1.029s | Train Loss: 0.021522 |
# INFO:root:| Epoch: 150/150 | Train Time: 1.019s | Train Loss: 0.021343 |
# INFO:root:Pretraining Time: 158.326s
# INFO:root:Finished pretraining.
# INFO:root:Testing autoencoder...
# INFO:root:Test Loss: 0.054296
# INFO:root:Test Time: 0.283s
# INFO:root:Finished testing autoencoder.
# INFO:root:Hey I am loading net for you!
# INFO:root:Setting hyper-parameters!
# INFO:root:Initializing center c...
# Learning rate: 0.0001
# INFO:root:Center c initialized.
# INFO:root:Starting training...
# INFO:root:| Epoch: 001/150 | Train Time: 0.951s | Train Loss: 0.057307 |
# INFO:root:| Epoch: 002/150 | Train Time: 0.939s | Train Loss: 0.012276 |
# INFO:root:| Epoch: 003/150 | Train Time: 0.921s | Train Loss: 0.006785 |
# INFO:root:| Epoch: 004/150 | Train Time: 0.928s | Train Loss: 0.004554 |
# INFO:root:| Epoch: 005/150 | Train Time: 0.898s | Train Loss: 0.003395 |
# INFO:root:| Epoch: 006/150 | Train Time: 0.906s | Train Loss: 0.002674 |
# INFO:root:| Epoch: 007/150 | Train Time: 0.956s | Train Loss: 0.002123 |
# INFO:root:| Epoch: 008/150 | Train Time: 1.009s | Train Loss: 0.001828 |
# INFO:root:| Epoch: 009/150 | Train Time: 0.843s | Train Loss: 0.001545 |
# INFO:root:| Epoch: 010/150 | Train Time: 0.868s | Train Loss: 0.001309 |
# INFO:root:| Epoch: 011/150 | Train Time: 0.930s | Train Loss: 0.001152 |
# INFO:root:| Epoch: 012/150 | Train Time: 0.923s | Train Loss: 0.001044 |
# INFO:root:| Epoch: 013/150 | Train Time: 0.937s | Train Loss: 0.000968 |
# INFO:root:| Epoch: 014/150 | Train Time: 0.941s | Train Loss: 0.000822 |
# INFO:root:| Epoch: 015/150 | Train Time: 0.958s | Train Loss: 0.000757 |
# INFO:root:| Epoch: 016/150 | Train Time: 0.961s | Train Loss: 0.000699 |
# INFO:root:| Epoch: 017/150 | Train Time: 0.984s | Train Loss: 0.000661 |
# INFO:root:| Epoch: 018/150 | Train Time: 0.951s | Train Loss: 0.000604 |
# INFO:root:| Epoch: 019/150 | Train Time: 0.966s | Train Loss: 0.000549 |
# INFO:root:| Epoch: 020/150 | Train Time: 0.893s | Train Loss: 0.000523 |
# INFO:root:| Epoch: 021/150 | Train Time: 0.954s | Train Loss: 0.000495 |
# INFO:root:| Epoch: 022/150 | Train Time: 1.007s | Train Loss: 0.000469 |
# INFO:root:| Epoch: 023/150 | Train Time: 0.929s | Train Loss: 0.000414 |
# INFO:root:| Epoch: 024/150 | Train Time: 0.942s | Train Loss: 0.000415 |
# INFO:root:| Epoch: 025/150 | Train Time: 0.855s | Train Loss: 0.000396 |
# INFO:root:| Epoch: 026/150 | Train Time: 0.928s | Train Loss: 0.000370 |
# INFO:root:| Epoch: 027/150 | Train Time: 0.818s | Train Loss: 0.000364 |
# INFO:root:| Epoch: 028/150 | Train Time: 0.965s | Train Loss: 0.000328 |
# INFO:root:| Epoch: 029/150 | Train Time: 0.902s | Train Loss: 0.000321 |
# INFO:root:| Epoch: 030/150 | Train Time: 0.919s | Train Loss: 0.000289 |
# INFO:root:| Epoch: 031/150 | Train Time: 0.910s | Train Loss: 0.000309 |
# INFO:root:| Epoch: 032/150 | Train Time: 1.000s | Train Loss: 0.000287 |
# INFO:root:| Epoch: 033/150 | Train Time: 0.955s | Train Loss: 0.000261 |
# INFO:root:| Epoch: 034/150 | Train Time: 0.921s | Train Loss: 0.000241 |
# INFO:root:| Epoch: 035/150 | Train Time: 0.868s | Train Loss: 0.000250 |
# INFO:root:| Epoch: 036/150 | Train Time: 0.909s | Train Loss: 0.000248 |
# INFO:root:| Epoch: 037/150 | Train Time: 0.929s | Train Loss: 0.000245 |
# INFO:root:| Epoch: 038/150 | Train Time: 0.869s | Train Loss: 0.000212 |
# INFO:root:| Epoch: 039/150 | Train Time: 0.927s | Train Loss: 0.000229 |
# INFO:root:| Epoch: 040/150 | Train Time: 0.924s | Train Loss: 0.000194 |
# INFO:root:| Epoch: 041/150 | Train Time: 0.876s | Train Loss: 0.000205 |
# INFO:root:| Epoch: 042/150 | Train Time: 0.936s | Train Loss: 0.000211 |
# INFO:root:| Epoch: 043/150 | Train Time: 0.942s | Train Loss: 0.000209 |
# INFO:root:| Epoch: 044/150 | Train Time: 0.972s | Train Loss: 0.000189 |
# INFO:root:| Epoch: 045/150 | Train Time: 0.914s | Train Loss: 0.000173 |
# INFO:root:| Epoch: 046/150 | Train Time: 0.919s | Train Loss: 0.000192 |
# INFO:root:| Epoch: 047/150 | Train Time: 0.915s | Train Loss: 0.000170 |
# INFO:root:| Epoch: 048/150 | Train Time: 0.896s | Train Loss: 0.000177 |
# INFO:root:| Epoch: 049/150 | Train Time: 0.959s | Train Loss: 0.000162 |
# INFO:root:| Epoch: 050/150 | Train Time: 0.936s | Train Loss: 0.000160 |
# INFO:root:  LR scheduler: new learning rate is 1e-06
# INFO:root:| Epoch: 051/150 | Train Time: 0.939s | Train Loss: 0.000142 |
# INFO:root:| Epoch: 052/150 | Train Time: 0.915s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 053/150 | Train Time: 0.946s | Train Loss: 0.000125 |
# INFO:root:| Epoch: 054/150 | Train Time: 0.950s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 055/150 | Train Time: 0.940s | Train Loss: 0.000143 |
# INFO:root:| Epoch: 056/150 | Train Time: 0.945s | Train Loss: 0.000136 |
# INFO:root:| Epoch: 057/150 | Train Time: 0.929s | Train Loss: 0.000145 |
# INFO:root:| Epoch: 058/150 | Train Time: 0.966s | Train Loss: 0.000135 |
# INFO:root:| Epoch: 059/150 | Train Time: 0.967s | Train Loss: 0.000136 |
# INFO:root:| Epoch: 060/150 | Train Time: 0.883s | Train Loss: 0.000123 |
# INFO:root:| Epoch: 061/150 | Train Time: 0.952s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 062/150 | Train Time: 0.962s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 063/150 | Train Time: 0.928s | Train Loss: 0.000135 |
# INFO:root:| Epoch: 064/150 | Train Time: 0.899s | Train Loss: 0.000124 |
# INFO:root:| Epoch: 065/150 | Train Time: 0.980s | Train Loss: 0.000138 |
# INFO:root:| Epoch: 066/150 | Train Time: 0.970s | Train Loss: 0.000119 |
# INFO:root:| Epoch: 067/150 | Train Time: 0.968s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 068/150 | Train Time: 0.952s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 069/150 | Train Time: 0.965s | Train Loss: 0.000127 |
# INFO:root:| Epoch: 070/150 | Train Time: 0.911s | Train Loss: 0.000135 |
# INFO:root:| Epoch: 071/150 | Train Time: 0.894s | Train Loss: 0.000117 |
# INFO:root:| Epoch: 072/150 | Train Time: 0.988s | Train Loss: 0.000135 |
# INFO:root:| Epoch: 073/150 | Train Time: 0.906s | Train Loss: 0.000137 |
# INFO:root:| Epoch: 074/150 | Train Time: 0.943s | Train Loss: 0.000120 |
# INFO:root:| Epoch: 075/150 | Train Time: 0.955s | Train Loss: 0.000112 |
# INFO:root:| Epoch: 076/150 | Train Time: 0.934s | Train Loss: 0.000118 |
# INFO:root:| Epoch: 077/150 | Train Time: 0.985s | Train Loss: 0.000138 |
# INFO:root:| Epoch: 078/150 | Train Time: 0.891s | Train Loss: 0.000122 |
# INFO:root:| Epoch: 079/150 | Train Time: 0.942s | Train Loss: 0.000129 |
# INFO:root:| Epoch: 080/150 | Train Time: 0.904s | Train Loss: 0.000116 |
# INFO:root:| Epoch: 081/150 | Train Time: 0.972s | Train Loss: 0.000119 |
# INFO:root:| Epoch: 082/150 | Train Time: 0.933s | Train Loss: 0.000117 |
# INFO:root:| Epoch: 083/150 | Train Time: 0.941s | Train Loss: 0.000122 |
# INFO:root:| Epoch: 084/150 | Train Time: 0.938s | Train Loss: 0.000126 |
# INFO:root:| Epoch: 085/150 | Train Time: 0.930s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 086/150 | Train Time: 0.961s | Train Loss: 0.000121 |
# INFO:root:| Epoch: 087/150 | Train Time: 0.883s | Train Loss: 0.000129 |
# INFO:root:| Epoch: 088/150 | Train Time: 0.974s | Train Loss: 0.000116 |
# INFO:root:| Epoch: 089/150 | Train Time: 0.978s | Train Loss: 0.000114 |
# INFO:root:| Epoch: 090/150 | Train Time: 0.981s | Train Loss: 0.000131 |
# INFO:root:| Epoch: 091/150 | Train Time: 0.934s | Train Loss: 0.000129 |
# INFO:root:| Epoch: 092/150 | Train Time: 0.918s | Train Loss: 0.000118 |
# INFO:root:| Epoch: 093/150 | Train Time: 0.886s | Train Loss: 0.000116 |
# INFO:root:| Epoch: 094/150 | Train Time: 0.946s | Train Loss: 0.000116 |
# INFO:root:| Epoch: 095/150 | Train Time: 0.931s | Train Loss: 0.000101 |
# INFO:root:| Epoch: 096/150 | Train Time: 1.025s | Train Loss: 0.000114 |
# INFO:root:| Epoch: 097/150 | Train Time: 0.941s | Train Loss: 0.000119 |
# INFO:root:| Epoch: 098/150 | Train Time: 1.115s | Train Loss: 0.000115 |
# INFO:root:| Epoch: 099/150 | Train Time: 0.990s | Train Loss: 0.000110 |
# INFO:root:| Epoch: 100/150 | Train Time: 0.993s | Train Loss: 0.000110 |
# INFO:root:  LR scheduler: new learning rate is 1e-07
# INFO:root:| Epoch: 101/150 | Train Time: 1.006s | Train Loss: 0.000107 |
# INFO:root:| Epoch: 102/150 | Train Time: 0.991s | Train Loss: 0.000108 |
# INFO:root:| Epoch: 103/150 | Train Time: 0.936s | Train Loss: 0.000101 |
# INFO:root:| Epoch: 104/150 | Train Time: 0.926s | Train Loss: 0.000100 |
# INFO:root:| Epoch: 105/150 | Train Time: 0.917s | Train Loss: 0.000108 |
# INFO:root:| Epoch: 106/150 | Train Time: 0.988s | Train Loss: 0.000096 |
# INFO:root:| Epoch: 107/150 | Train Time: 1.044s | Train Loss: 0.000109 |
# INFO:root:| Epoch: 108/150 | Train Time: 0.979s | Train Loss: 0.000102 |
# INFO:root:| Epoch: 109/150 | Train Time: 0.918s | Train Loss: 0.000107 |
# INFO:root:| Epoch: 110/150 | Train Time: 0.926s | Train Loss: 0.000106 |
# INFO:root:| Epoch: 111/150 | Train Time: 0.914s | Train Loss: 0.000109 |
# INFO:root:| Epoch: 112/150 | Train Time: 0.939s | Train Loss: 0.000109 |
# INFO:root:| Epoch: 113/150 | Train Time: 0.936s | Train Loss: 0.000104 |
# INFO:root:| Epoch: 114/150 | Train Time: 0.953s | Train Loss: 0.000096 |
# INFO:root:| Epoch: 115/150 | Train Time: 0.887s | Train Loss: 0.000102 |
# INFO:root:| Epoch: 116/150 | Train Time: 0.971s | Train Loss: 0.000102 |
# INFO:root:| Epoch: 117/150 | Train Time: 0.921s | Train Loss: 0.000109 |
# INFO:root:| Epoch: 118/150 | Train Time: 0.880s | Train Loss: 0.000112 |
# INFO:root:| Epoch: 119/150 | Train Time: 0.907s | Train Loss: 0.000106 |
# INFO:root:| Epoch: 120/150 | Train Time: 0.897s | Train Loss: 0.000114 |
# INFO:root:| Epoch: 121/150 | Train Time: 0.954s | Train Loss: 0.000110 |
# INFO:root:| Epoch: 122/150 | Train Time: 0.967s | Train Loss: 0.000115 |
# INFO:root:| Epoch: 123/150 | Train Time: 0.910s | Train Loss: 0.000102 |
# INFO:root:| Epoch: 124/150 | Train Time: 0.874s | Train Loss: 0.000112 |
# INFO:root:| Epoch: 125/150 | Train Time: 0.922s | Train Loss: 0.000100 |
# INFO:root:| Epoch: 126/150 | Train Time: 0.907s | Train Loss: 0.000098 |
# INFO:root:| Epoch: 127/150 | Train Time: 0.959s | Train Loss: 0.000106 |
# INFO:root:| Epoch: 128/150 | Train Time: 0.930s | Train Loss: 0.000104 |
# INFO:root:| Epoch: 129/150 | Train Time: 0.938s | Train Loss: 0.000106 |
# INFO:root:| Epoch: 130/150 | Train Time: 0.957s | Train Loss: 0.000113 |
# INFO:root:| Epoch: 131/150 | Train Time: 0.932s | Train Loss: 0.000109 |
# INFO:root:| Epoch: 132/150 | Train Time: 0.855s | Train Loss: 0.000106 |
# INFO:root:| Epoch: 133/150 | Train Time: 0.965s | Train Loss: 0.000103 |
# INFO:root:| Epoch: 134/150 | Train Time: 0.953s | Train Loss: 0.000107 |
# INFO:root:| Epoch: 135/150 | Train Time: 0.866s | Train Loss: 0.000103 |
# INFO:root:| Epoch: 136/150 | Train Time: 0.787s | Train Loss: 0.000105 |
# INFO:root:| Epoch: 137/150 | Train Time: 0.895s | Train Loss: 0.000108 |
# INFO:root:| Epoch: 138/150 | Train Time: 0.911s | Train Loss: 0.000116 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.943s | Train Loss: 0.000109 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.827s | Train Loss: 0.000094 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.852s | Train Loss: 0.000100 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.882s | Train Loss: 0.000104 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.888s | Train Loss: 0.000103 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.872s | Train Loss: 0.000101 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.804s | Train Loss: 0.000099 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.787s | Train Loss: 0.000101 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.816s | Train Loss: 0.000100 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.830s | Train Loss: 0.000107 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.887s | Train Loss: 0.000100 |
# INFO:root:| Epoch: 150/150 | Train Time: 0.881s | Train Loss: 0.000100 |
# INFO:root:Training Time: 139.456s
# INFO:root:Finished training.

# %%
model.test(dataset, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:Starting testing...
# INFO:root:Test Loss: 345.314608
# INFO:root:Test AUC: 79.38%
# INFO:root:Test Time: 0.280s
# INFO:root:Finished testing.

# %%
model.save_model(export_model=model_path, save_ae=save_ae)

# %%
indices_, labels_, scores_ = zip(*model.results['test_scores'])
indices_, labels_, scores_ = np.array(indices_), np.array(labels_), np.array(scores_)
result_df = pd.DataFrame()
result_df['indices'] = indices_; result_df['labels'] = labels_; result_df['scores'] = scores_

result_df.drop('indices', inplace=True, axis=1)
df_normal = result_df[result_df.labels.isin(label_normal)]
df_abnormal = result_df[result_df.labels.isin(label_abnormal)]

cut_90 = df_normal.scores.quantile(0.90)
# np.save(cut_90_path, cut_90)

cut_95 = df_normal.scores.quantile(0.95)
# np.save(cut_95_path, cut_95)

cut_99 = df_normal.scores.quantile(0.99)
# np.save(cut_99_path, cut_99)

# %%
label_eval_list = [(i,) for i in range(10)]
total_roc_auc = []
total_recall_90 = []
total_recall_95 = []
total_recall_99 = []

for label_eval in label_eval_list:
    # Formating the path
    test_eval = False
    if (label_eval[0] in label_normal) or (label_eval[0] in label_abnormal):
        test_eval = True
        
    # Start evaluating
    dataset_eval = load_dataset(loader_name=loader_eval_name,
                                root=root,
                                label_eval=label_eval,
                                test_eval=test_eval)

    # Load model for evaluation
    if optimizer_ in ['one_class', 'one_class_unsupervised']:
        model_eval = OneClassModelEval(optimizer_, eta=eta)
    elif optimizer_ in ['rec', 'rec_unsupervised']:
        model_eval = RecModelEval(optimizer_, eta=eta)

    model_eval.set_network(net_name)
    model_eval.load_model(model_path=model_path, map_location=device)
    model_eval.test(dataset_eval,
                    eta=eta,
                    batch_size=batch_size,
                    device=device,
                    n_jobs_dataloader=n_jobs_dataloader,
                    label_normal=label_normal)
    _, labels, scores = zip(*model_eval.results['test_scores'])

    # Get predicted label
    y_90 = [1 if e > cut_90 else 0 for e in scores]
    y_95 = [1 if e > cut_95 else 0 for e in scores]
    y_99 = [1 if e > cut_99 else 0 for e in scores]

    if label_eval[0] in label_normal:
        print('Skip self!')
    else:
        # Record results when FP = 0.10
        recall_90 = sum(y_90) / len(y_90)
        total_recall_90.append(recall_90)
        msg = '[Recall for class {} (FP = 0.10)] {}\n'.format(label_eval[0], recall_90)
        print(msg)
        
        # Record results when FP = 0.05
        recall_95 = sum(y_95) / len(y_95)
        total_recall_95.append(recall_95)
        msg = '[Recall for class {} (FP = 0.05)] {}\n'.format(label_eval[0], recall_95)
        print(msg)
# Out:
# Starting evaluating...
# Test Loss: 0.000308
# Test Time: 0.110s
# Finished testing.
# Skip self!
# Starting evaluating...
# Test Loss: 814.456652
# Test Time: 0.775s
# Finished testing.
# [Recall for class 1 (FP = 0.10)] 0.40685714285714286
#
# [Recall for class 1 (FP = 0.05)] 0.2572857142857143
#
# Starting evaluating...
# Test Loss: 939.199149
# Test Time: 0.767s
# Finished testing.
# [Recall for class 2 (FP = 0.10)] 0.3707142857142857
#
# [Recall for class 2 (FP = 0.05)] 0.23785714285714285
#
# Starting evaluating...
# Test Loss: 1008.522662
# Test Time: 0.837s
# Finished testing.
# [Recall for class 3 (FP = 0.10)] 0.328
#
# [Recall for class 3 (FP = 0.05)] 0.1947142857142857
#
# Starting evaluating...
# Test Loss: 895.220678
# Test Time: 0.759s
# Finished testing.
# [Recall for class 4 (FP = 0.10)] 0.37714285714285717
#
# [Recall for class 4 (FP = 0.05)] 0.2412857142857143
#
# Starting evaluating...
# Test Loss: 549.959796
# Test Time: 0.819s
# Finished testing.
# [Recall for class 5 (FP = 0.10)] 0.5908571428571429
#
# [Recall for class 5 (FP = 0.05)] 0.4552857142857143
#
# Starting evaluating...
# Test Loss: 1504.986466
# Test Time: 0.773s
# Finished testing.
# [Recall for class 6 (FP = 0.10)] 0.26671428571428574
#
# [Recall for class 6 (FP = 0.05)] 0.1682857142857143
#
# Starting evaluating...
# Test Loss: 684.700863
# Test Time: 0.107s
# Finished testing.
# [Recall for class 7 (FP = 0.10)] 0.445
#
# [Recall for class 7 (FP = 0.05)] 0.305
#
# Starting evaluating...
# Test Loss: 434.300424
# Test Time: 0.759s
# Finished testing.
# [Recall for class 8 (FP = 0.10)] 0.6284285714285714
#
# [Recall for class 8 (FP = 0.05)] 0.498
#
# Starting evaluating...
# Test Loss: 306.857787
# Test Time: 0.757s
# Finished testing.
# [Recall for class 9 (FP = 0.10)] 0.7052857142857143
#
# [Recall for class 9 (FP = 0.05)] 0.592

# %% [markdown]
# Training results is good! Seems that even if the latent dimensions have been compressed to just 2, it can still do works.

# %% [markdown]
# # 3. Extract the Encoder Part

# %%
class RecEncoder:
    def __init__(self):

        self.net_name = None
        self.net = None
        self.ae_net = None


    def set_network(self, net_name: str='fmnist_LeNet_one_class'):
        """
        Set the network structure for the model.
        The key here is to initialize <self.net>.
        """
        self.net_name = net_name
        self.net = build_network(net_name)
        self.ae_net = build_network('fmnist_LeNet_rec')

    def load_model(self,
                   model_path,
                   load_ae=False,
                   map_location='cuda:1'):
        """
        Load the trained model for the model.
        The key here is to initialize <self.c>.
        """
        # Load the general model
        model_dict = torch.load(model_path, map_location=map_location)
        self.ae_net.load_state_dict(model_dict['net_dict'])
        
        # Obtain the net dictionary
        net_dict = self.net.state_dict()
        ae_net_dict = self.ae_net.state_dict()
        
        # Filter out decoder network keys
        ae_net_dict = {k: v for k, v in ae_net_dict.items() if k in net_dict}
        
        # Overwrite values in the existing state_dict
        net_dict.update(ae_net_dict)

        # Load the new state_dict
        self.net.load_state_dict(net_dict)
        

    def save_model(self, export_model, save_ae=True):
        net_dict = self.net.state_dict()
        torch.save({'net_dict': net_dict}, export_model)
    
    def test(self, dataset, device, batch_size, n_jobs_dataloader):
        all_loader = dataset.loaders(batch_size=batch_size,
                                     num_workers=n_jobs_dataloader)
        net = self.net.to(device)
        criterion = nn.MSELoss(reduction='none')
        
        n_batches = 0
        X_pred_list = []
        net.eval()
        
        with torch.no_grad():
            for data in all_loader:
                X, y, idx = data
                X, y, idx = X.to(device), y.to(device), idx.to(device)

                X_pred = net(X)
                X_pred_list += X_pred
        
        return np.array(X_pred_list)

# %%
encoder = RecEncoder()
encoder.set_network()

# %%
dataset_eval_list = []
for label_eval in label_eval_list:
    dataset_eval_list.append(load_dataset(loader_name=loader_eval_name,
                                          root=root,
                                          label_eval=label_eval,
                                          test_eval=False))

# %%
data_list = []
for dataset_eval in dataset_eval_list:
    data = encoder.test(dataset_eval, device, batch_size, n_jobs_dataloader)
    data = np.array([x.cpu().numpy() for x in data])
    data_list.append(data.T)

# %%
color_dict = {'tshirt':0,
              'shirt': 1,
              'dress':2,
              'pullover':3,
              'coat':4,
              'trouser':5,
               'bag': 6,
              'boot': 7,
              'sandal': 8,
              'sneaker':9}

num_to_letter ={0: 'tshirt', 
                1: 'trouser', 
                2: 'pullover', 
                3: 'dress', 
                4: 'coat',
                5: 'sandal', 
                6: 'shirt', 
                7: 'sneaker', 
                8: 'bag', 
                9: 'boot'}

letter_to_num = {v:k for k, v in num_to_letter.items()}

fig, ax = plt.subplots(figsize=(20, 10))

for letter in list(color_dict)[::-1]:
    label = letter_to_num[letter]
    data = data_list[label]
    cluster = sns.scatterplot(x=data[0], y=data[1], label=letter, alpha=0.2, color=sns.color_palette("hls", 12)[2:][color_dict[letter]])

plt.legend()
plt.title('Semi-supervised One Class Model Using tshirt as Normal and sneaker as Abnormal (most different)')
plt.ylim(-0.055, 0.20)
plt.xlim(-0.25, 0.10)
sns.despine()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

for i, data in enumerate(data_list):
    cluster = sns.scatterplot(x=data[0], y=data[1], label=label_dict[i], alpha=0.2, color=sns.color_palette("hls", 10)[i])

plt.legend()
plt.title('Semi-supervised One Class Model Using tshirt as Normal and sneaker as Abnormal (most different)')
plt.ylim(-0.055, 0.20)
plt.xlim(-0.25, 0.10)
sns.despine()
