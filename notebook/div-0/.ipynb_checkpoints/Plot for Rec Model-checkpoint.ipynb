# %%
import pandas as pd
import numpy as np
import joblib
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# # Obtain $y$

# %%
root = '/net/leksai/nips/result/fmnist'
recall_rec = pd.read_pickle(Path(root)/'recall_df_{}_90.pkl'.format(0))['Reconstruction Model']
# recall_oc = pd.read_pickle(Path(root)/'recall_df_{}_90.pkl'.format(0))['One Class Model']

# %%
recall_rec
# Out:
#    A/N = 0  A/N = 0.1, Abnormal: 1  A/N = 0.1, Abnormal: 2  \
# 1    0.804                   0.996                   0.699
# 2    0.542                   0.608                   0.979
# 3    0.288                   0.552                   0.317
# 4    0.486                   0.668                   0.965
# 5    0.903                   0.925                   0.889
# 6    0.347                   0.333                   0.653
# 7    0.827                   0.909                   0.930
# 8    0.922                   0.894                   0.939
# 9    0.998                   0.999                   0.999
#
#    A/N = 0.1, Abnormal: 3  A/N = 0.1, Abnormal: 4  A/N = 0.1, Abnormal: 5  \
# 1                   0.918                   0.844                   0.810
# 2                   0.549                   0.952                   0.525
# 3                   0.963                   0.467                   0.308
# 4                   0.661                   0.995                   0.460
# 5                   0.834                   0.903                   1.000
# 6                   0.358                   0.658                   0.313
# 7                   0.902                   0.922                   1.000
# 8                   0.920                   0.932                   0.969
# 9                   0.994                   0.993                   1.000
#
#    A/N = 0.1, Abnormal: 6  A/N = 0.1, Abnormal: 7  A/N = 0.1, Abnormal: 8  \
# 1                   0.387                   0.807                   0.735
# 2                   0.900                   0.591                   0.677
# 3                   0.369                   0.299                   0.304
# 4                   0.931                   0.501                   0.824
# 5                   0.492                   0.999                   0.990
# 6                   0.777                   0.350                   0.430
# 7                   0.291                   1.000                   0.999
# 8                   0.700                   0.960                   0.998
# 9                   0.923                   1.000                   1.000
#
#    A/N = 0.1, Abnormal: 9
# 1                   0.785
# 2                   0.549
# 3                   0.330
# 4                   0.486
# 5                   0.982
# 6                   0.342
# 7                   1.000
# 8                   0.947
# 9                   1.000

# %%
y_un = {k: {} for k in range(1, 10)}
y_semi = {k: {} for k in range(1, 10)}

# %%
# y_un[i] refers to the unsupervised results on test abnormal i
# y_semi[i] refers to the semi-supervised results on test abnormal i

for i in range(1, 10):
    y_un[i] = [recall_rec.loc[i, :][0]] * 9
    y_semi[i] = list(recall_rec.loc[i, :][1:])

# %%
y_un
# Out:
# {1: [0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804, 0.804],
#  2: [0.542, 0.542, 0.542, 0.542, 0.542, 0.542, 0.542, 0.542, 0.542],
#  3: [0.288, 0.288, 0.288, 0.288, 0.288, 0.288, 0.288, 0.288, 0.288],
#  4: [0.486, 0.486, 0.486, 0.486, 0.486, 0.486, 0.486, 0.486, 0.486],
#  5: [0.903, 0.903, 0.903, 0.903, 0.903, 0.903, 0.903, 0.903, 0.903],
#  6: [0.347, 0.347, 0.347, 0.347, 0.347, 0.347, 0.347, 0.347, 0.347],
#  7: [0.827, 0.827, 0.827, 0.827, 0.827, 0.827, 0.827, 0.827, 0.827],
#  8: [0.922, 0.922, 0.922, 0.922, 0.922, 0.922, 0.922, 0.922, 0.922],
#  9: [0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998, 0.998]}

# %%
y_semi
# Out:
# {1: [0.996, 0.699, 0.918, 0.844, 0.81, 0.387, 0.807, 0.735, 0.785],
#  2: [0.608, 0.979, 0.549, 0.952, 0.525, 0.9, 0.591, 0.677, 0.549],
#  3: [0.552, 0.317, 0.963, 0.467, 0.308, 0.369, 0.299, 0.304, 0.33],
#  4: [0.668, 0.965, 0.661, 0.995, 0.46, 0.931, 0.501, 0.824, 0.486],
#  5: [0.925, 0.889, 0.834, 0.903, 1.0, 0.492, 0.999, 0.99, 0.982],
#  6: [0.333, 0.653, 0.358, 0.658, 0.313, 0.777, 0.35, 0.43, 0.342],
#  7: [0.909, 0.93, 0.902, 0.922, 1.0, 0.291, 1.0, 0.999, 1.0],
#  8: [0.894, 0.939, 0.92, 0.932, 0.969, 0.7, 0.96, 0.998, 0.947],
#  9: [0.999, 0.999, 0.994, 0.993, 1.0, 0.923, 1.0, 1.0, 1.0]}

# %% [markdown]
# # Obtain $x$

# %%
div_joint_rec = joblib.load('div_joint.pkl')
div_margin_rec = joblib.load('div_margin.pkl')

# %%
name_list = ['tshirt', 'trouser', 'pullover', 'dress', 'coat',
             'sandal', 'shirt', 'sneaker', 'bag', 'boot']

# %%
x_joint = {k: {} for k in range(1, 10)}
x_margin = {k: {} for k in range(1, 10)}

# %%
for i in range(1, 10):
    name = name_list[i]
    x_joint[i] = list(div_joint_rec[name].values())
    x_margin[i] = list(div_margin_rec[name].values())

# %%
x_joint
# Out:
# {1: [-0.01998289193292102,
#   16.719424922947773,
#   11.818667496670319,
#   16.43131129532984,
#   18.11249506145907,
#   14.009425283623434,
#   24.03513190388634,
#   17.707023228512405,
#   21.918086379161664],
#  2: [17.098063284723622,
#   0.08035840202867028,
#   10.064926724454747,
#   3.284572523378163,
#   12.093500256222736,
#   2.449588624186063,
#   18.22156787940762,
#   10.956769268891783,
#   15.139835665785684],
#  3: [12.155899369528553,
#   9.669065748474775,
#   0.07773588147370747,
#   8.486002222168805,
#   11.479863853768041,
#   6.874608036209636,
#   17.42289862391659,
#   11.06516330186731,
#   15.12281989369342],
#  4: [17.15886577650378,
#   3.267450353635983,
#   9.207277801765642,
#   -0.04747840595703279,
#   13.11137106115546,
#   2.8717510459062696,
#   19.13101153807626,
#   11.505058808723755,
#   16.179716311762927],
#  5: [19.37568322650946,
#   12.8501783529138,
#   12.77592724420801,
#   13.678723828282976,
#   -0.0648074804145593,
#   10.566532020300595,
#   7.245308283021264,
#   11.625098952330578,
#   10.643357590576983],
#  6: [14.438736866130421,
#   2.690625840709045,
#   7.408768834156867,
#   3.19596410481884,
#   9.824084139025926,
#   -0.0049532797398561534,
#   15.793281436486385,
#   8.848114246391352,
#   13.25905845526331],
#  7: [25.725785143171983,
#   19.33671766825735,
#   19.099988004179835,
#   20.251091842064014,
#   6.769964714768191,
#   16.803850033714948,
#   -0.03796889553393834,
#   15.899344170974754,
#   11.822609193222902],
#  8: [18.398751242430055,
#   11.061233815429848,
#   11.793354341567118,
#   11.476261651850468,
#   11.098249068711764,
#   8.74243829363647,
#   15.21271902900405,
#   0.014897841226382713,
#   16.013555886305717],
#  9: [23.27141067055368,
#   16.43673060092133,
#   16.373514404538057,
#   16.94942835373594,
#   10.463237824669424,
#   14.18883298739642,
#   11.104677543091926,
#   16.878834724195066,
#   -0.015025219877348395]}

# %%
x_margin
# Out:
# {1: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  2: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  3: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  4: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  5: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  6: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  7: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  8: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504],
#  9: [41.86391770552747,
#   26.21745876800793,
#   21.693192971664143,
#   29.42408069558971,
#   43.89401473305362,
#   11.533652712642787,
#   58.191590372146806,
#   34.54752332904317,
#   50.38283941276504]}

# %% [markdown]
# # Draw Plots for Joint Divergence

# %%
margin_test_for_tshirt = joblib.load('margin_test_for_tshirt.pkl')

# %%
i = 6

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %% [markdown]
# 2

# %%
i = 3

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 2

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 4

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 8

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 1

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 5

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 9

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %%
i = 7

# %%
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
joint_x = np.array(x_joint[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(joint_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(joint_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(joint_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(joint_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(joint_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Source and Target – KL(P_train || P_test)')
plt.title('[Recall v.s. KL(P_train || P_test)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(-2, 26)
plt.show()

# %% [markdown]
# # Draw Plots for Marginal Divergence

# %%
i = 6
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 3
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 2
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 4
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 8
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 1
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 5
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 9
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()

# %%
i = 7
y0 = np.array(y_un[i])
y1 = np.array(y_semi[i])
margin_x = np.array(x_margin[i])

dy = y1 - y0
pos_ind = np.where(dy >= 0)[0]
nega_ind = np.where(dy < 0)[0]

plt.figure(figsize=(18, 6))
plt.plot(margin_x[pos_ind], y0[pos_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y0[nega_ind], '.', color='black', markersize=10, alpha=0.8)
plt.plot(margin_x[pos_ind], y1[pos_ind], '^', color='green', markersize=10, alpha=0.8)
plt.plot(margin_x[nega_ind], y1[nega_ind], 'v', color='red', markersize=10, alpha=0.8)


for j in range(len(y0)):
    # The follow line only works when normal = 0
    if i == j + 1:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='orange')  
    elif y0[j]-y1[j] >= 0:
        plt.arrow(margin_x[j], y0[j], 0, y1[j] - y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='red')
    else:
        plt.arrow(margin_x[j], y0[j], 0, y1[j]-y0[j],
              width=0.001, length_includes_head=True, head_length=0.01, color='green')

sns.despine()
plt.ylabel('Recall')
plt.xlabel('KL Divergence between Train Normal and Train Abnormal – KL(P_train_normal || P_train_abnormal)')
plt.title('[Recall v.s. KL(P_train_normal || P_train_abnormal)]. Normal: tshirt. Test: {}. KL(P_test_normal || P_test_abnormal)={}'.format(name_list[i], round(margin_test_for_tshirt[i], 1)))
plt.ylim(0, 1.1)
plt.xlim(9, 61)
plt.show()
