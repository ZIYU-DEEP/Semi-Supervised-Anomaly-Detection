# %%
import sys
sys.path.append('../dataset/')
sys.path.append('../network/')
sys.path.append('../model/')

import os
import glob
import time
import torch
import logging
import argparse
import numpy as np
import pandas as pd
import torch.optim as optim
import torch.nn as nn
import torch
import seaborn as sns

from pathlib import Path
from main_loading import *
from main_network import *
from main_model_rec import *
from main_model_one_class import *
from sklearn.metrics import roc_auc_score
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'

# %% [markdown]
# > Modified things in local:
# - Changed the `network/main_network.py`, add a new term rep_dim and changed them all to 2.

# %% [markdown]
# # 0. Variable Definitions

# %%
# For data
root = '/net/leksai/data/FashionMNIST'
loader_name = 'fmnist'
loader_eval_name = 'fmnist_eval'
label_normal = (0,)
label_abnormal = (7,)
ratio_abnormal = 0.1

# For model
pretrain = True
net_name = 'fmnist_LeNet_one_class'
optimizer_ = 'one_class'
eta = 0.1
optimizer_name = 'adam'
lr = 0.0001
ae_lr = 0.001
n_epochs = 150
ae_n_epochs = 150
lr_milestones = (50, 100, 150)
batch_size = 128
weight_decay = 0.5e-6
ae_weight_decay = 0.5e-3
device_no = 2
device = 'cuda:0'
n_jobs_dataloader = 0
save_ae = True
load_ae = False

log_path = 'misc/one_class_fmnist_0_7.log'
model_path = 'misc/one_class_fmnist_0_7.tar'

# %%
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger()
logger.setLevel(logging.INFO)
formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
file_handler = logging.FileHandler(log_path)
file_handler.setLevel(logging.INFO)
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)

# %% [markdown]
# # 1. Load Dataset

# %%
dataset = load_dataset(loader_name=loader_name,
                       root=root,
                       label_normal=label_normal,
                       label_abnormal=label_abnormal,
                       ratio_abnormal=ratio_abnormal)
# Out:
# Loading dataset for you!
# Almost loaded!

# %% [markdown]
# # 2. Load Model

# %%
model = OneClassModel(optimizer_, eta)
model.set_network(net_name)
logger.info('I am pre-training for you.')
model.pretrain(dataset, optimizer_name, ae_lr, ae_n_epochs, lr_milestones,
               batch_size, ae_weight_decay, device, n_jobs_dataloader)
model.train(dataset, eta, optimizer_name, lr, n_epochs, lr_milestones,
            batch_size, weight_decay, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:I am pre-training for you.
# /home/ziyuye/env/lib/python3.6/site-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# INFO:root:| Epoch: 001/150 | Train Time: 1.077s | Train Loss: 0.048772 |
# INFO:root:| Epoch: 002/150 | Train Time: 1.093s | Train Loss: 0.028040 |
# INFO:root:| Epoch: 003/150 | Train Time: 1.094s | Train Loss: 0.026609 |
# INFO:root:| Epoch: 004/150 | Train Time: 0.965s | Train Loss: 0.026271 |
# INFO:root:| Epoch: 005/150 | Train Time: 1.050s | Train Loss: 0.025850 |
# INFO:root:| Epoch: 006/150 | Train Time: 1.065s | Train Loss: 0.025337 |
# INFO:root:| Epoch: 007/150 | Train Time: 0.989s | Train Loss: 0.025262 |
# INFO:root:| Epoch: 008/150 | Train Time: 1.016s | Train Loss: 0.024965 |
# INFO:root:| Epoch: 009/150 | Train Time: 1.014s | Train Loss: 0.025026 |
# INFO:root:| Epoch: 010/150 | Train Time: 1.037s | Train Loss: 0.025159 |
# INFO:root:| Epoch: 011/150 | Train Time: 1.006s | Train Loss: 0.024869 |
# INFO:root:| Epoch: 012/150 | Train Time: 1.023s | Train Loss: 0.024743 |
# INFO:root:| Epoch: 013/150 | Train Time: 1.023s | Train Loss: 0.024947 |
# INFO:root:| Epoch: 014/150 | Train Time: 0.982s | Train Loss: 0.024513 |
# INFO:root:| Epoch: 015/150 | Train Time: 1.032s | Train Loss: 0.024663 |
# INFO:root:| Epoch: 016/150 | Train Time: 1.074s | Train Loss: 0.024464 |
# INFO:root:| Epoch: 017/150 | Train Time: 1.042s | Train Loss: 0.024520 |
# INFO:root:| Epoch: 018/150 | Train Time: 1.087s | Train Loss: 0.024343 |
# INFO:root:| Epoch: 019/150 | Train Time: 1.063s | Train Loss: 0.024621 |
# INFO:root:| Epoch: 020/150 | Train Time: 1.012s | Train Loss: 0.024623 |
# INFO:root:| Epoch: 021/150 | Train Time: 0.989s | Train Loss: 0.024560 |
# INFO:root:| Epoch: 022/150 | Train Time: 0.978s | Train Loss: 0.024239 |
# INFO:root:| Epoch: 023/150 | Train Time: 0.995s | Train Loss: 0.024371 |
# INFO:root:| Epoch: 024/150 | Train Time: 1.041s | Train Loss: 0.024740 |
# INFO:root:| Epoch: 025/150 | Train Time: 1.024s | Train Loss: 0.024305 |
# INFO:root:| Epoch: 026/150 | Train Time: 0.981s | Train Loss: 0.024375 |
# INFO:root:| Epoch: 027/150 | Train Time: 1.017s | Train Loss: 0.024288 |
# INFO:root:| Epoch: 028/150 | Train Time: 1.031s | Train Loss: 0.024429 |
# INFO:root:| Epoch: 029/150 | Train Time: 1.075s | Train Loss: 0.024420 |
# INFO:root:| Epoch: 030/150 | Train Time: 0.977s | Train Loss: 0.024516 |
# INFO:root:| Epoch: 031/150 | Train Time: 1.050s | Train Loss: 0.024316 |
# INFO:root:| Epoch: 032/150 | Train Time: 1.041s | Train Loss: 0.024467 |
# INFO:root:| Epoch: 033/150 | Train Time: 0.999s | Train Loss: 0.024695 |
# INFO:root:| Epoch: 034/150 | Train Time: 1.079s | Train Loss: 0.024206 |
# INFO:root:| Epoch: 035/150 | Train Time: 1.201s | Train Loss: 0.024188 |
# INFO:root:| Epoch: 036/150 | Train Time: 1.110s | Train Loss: 0.024133 |
# INFO:root:| Epoch: 037/150 | Train Time: 1.052s | Train Loss: 0.024106 |
# INFO:root:| Epoch: 038/150 | Train Time: 1.068s | Train Loss: 0.024263 |
# INFO:root:| Epoch: 039/150 | Train Time: 1.074s | Train Loss: 0.024203 |
# INFO:root:| Epoch: 040/150 | Train Time: 0.976s | Train Loss: 0.024424 |
# INFO:root:| Epoch: 041/150 | Train Time: 1.012s | Train Loss: 0.024146 |
# INFO:root:| Epoch: 042/150 | Train Time: 1.045s | Train Loss: 0.023952 |
# INFO:root:| Epoch: 043/150 | Train Time: 1.087s | Train Loss: 0.024190 |
# INFO:root:| Epoch: 044/150 | Train Time: 0.991s | Train Loss: 0.024303 |
# INFO:root:| Epoch: 045/150 | Train Time: 1.077s | Train Loss: 0.024084 |
# INFO:root:| Epoch: 046/150 | Train Time: 1.024s | Train Loss: 0.024173 |
# INFO:root:| Epoch: 047/150 | Train Time: 1.110s | Train Loss: 0.024046 |
# INFO:root:| Epoch: 048/150 | Train Time: 1.144s | Train Loss: 0.024133 |
# INFO:root:| Epoch: 049/150 | Train Time: 1.104s | Train Loss: 0.024095 |
# INFO:root:| Epoch: 050/150 | Train Time: 1.086s | Train Loss: 0.023127 |
# INFO:root:  LR scheduler: new learning rate is 0.0001
# INFO:root:| Epoch: 051/150 | Train Time: 1.137s | Train Loss: 0.022794 |
# INFO:root:| Epoch: 052/150 | Train Time: 1.091s | Train Loss: 0.022918 |
# INFO:root:| Epoch: 053/150 | Train Time: 1.108s | Train Loss: 0.022805 |
# INFO:root:| Epoch: 054/150 | Train Time: 1.145s | Train Loss: 0.022722 |
# INFO:root:| Epoch: 055/150 | Train Time: 1.215s | Train Loss: 0.022699 |
# INFO:root:| Epoch: 056/150 | Train Time: 1.059s | Train Loss: 0.022616 |
# INFO:root:| Epoch: 057/150 | Train Time: 1.144s | Train Loss: 0.022575 |
# INFO:root:| Epoch: 058/150 | Train Time: 1.054s | Train Loss: 0.022595 |
# INFO:root:| Epoch: 059/150 | Train Time: 1.177s | Train Loss: 0.022534 |
# INFO:root:| Epoch: 060/150 | Train Time: 1.118s | Train Loss: 0.022417 |
# INFO:root:| Epoch: 061/150 | Train Time: 1.233s | Train Loss: 0.022482 |
# INFO:root:| Epoch: 062/150 | Train Time: 1.099s | Train Loss: 0.022519 |
# INFO:root:| Epoch: 063/150 | Train Time: 1.151s | Train Loss: 0.022566 |
# INFO:root:| Epoch: 064/150 | Train Time: 1.087s | Train Loss: 0.022512 |
# INFO:root:| Epoch: 065/150 | Train Time: 1.197s | Train Loss: 0.022392 |
# INFO:root:| Epoch: 066/150 | Train Time: 1.124s | Train Loss: 0.022568 |
# INFO:root:| Epoch: 067/150 | Train Time: 1.048s | Train Loss: 0.022365 |
# INFO:root:| Epoch: 068/150 | Train Time: 1.124s | Train Loss: 0.022495 |
# INFO:root:| Epoch: 069/150 | Train Time: 1.044s | Train Loss: 0.022355 |
# INFO:root:| Epoch: 070/150 | Train Time: 1.168s | Train Loss: 0.022303 |
# INFO:root:| Epoch: 071/150 | Train Time: 1.214s | Train Loss: 0.022245 |
# INFO:root:| Epoch: 072/150 | Train Time: 1.052s | Train Loss: 0.022452 |
# INFO:root:| Epoch: 073/150 | Train Time: 1.176s | Train Loss: 0.022289 |
# INFO:root:| Epoch: 074/150 | Train Time: 1.065s | Train Loss: 0.022219 |
# INFO:root:| Epoch: 075/150 | Train Time: 1.130s | Train Loss: 0.022209 |
# INFO:root:| Epoch: 076/150 | Train Time: 1.162s | Train Loss: 0.022317 |
# INFO:root:| Epoch: 077/150 | Train Time: 1.105s | Train Loss: 0.022359 |
# INFO:root:| Epoch: 078/150 | Train Time: 1.178s | Train Loss: 0.022202 |
# INFO:root:| Epoch: 079/150 | Train Time: 1.104s | Train Loss: 0.022154 |
# INFO:root:| Epoch: 080/150 | Train Time: 1.206s | Train Loss: 0.022267 |
# INFO:root:| Epoch: 081/150 | Train Time: 1.099s | Train Loss: 0.022339 |
# INFO:root:| Epoch: 082/150 | Train Time: 1.159s | Train Loss: 0.022269 |
# INFO:root:| Epoch: 083/150 | Train Time: 1.099s | Train Loss: 0.022198 |
# INFO:root:| Epoch: 084/150 | Train Time: 1.201s | Train Loss: 0.022269 |
# INFO:root:| Epoch: 085/150 | Train Time: 1.140s | Train Loss: 0.022206 |
# INFO:root:| Epoch: 086/150 | Train Time: 1.110s | Train Loss: 0.022375 |
# INFO:root:| Epoch: 087/150 | Train Time: 1.183s | Train Loss: 0.022123 |
# INFO:root:| Epoch: 088/150 | Train Time: 1.190s | Train Loss: 0.022268 |
# INFO:root:| Epoch: 089/150 | Train Time: 1.158s | Train Loss: 0.022104 |
# INFO:root:| Epoch: 090/150 | Train Time: 1.183s | Train Loss: 0.022038 |
# INFO:root:| Epoch: 091/150 | Train Time: 1.172s | Train Loss: 0.022195 |
# INFO:root:| Epoch: 092/150 | Train Time: 1.095s | Train Loss: 0.022019 |
# INFO:root:| Epoch: 093/150 | Train Time: 1.115s | Train Loss: 0.022236 |
# INFO:root:| Epoch: 094/150 | Train Time: 1.072s | Train Loss: 0.021931 |
# INFO:root:| Epoch: 095/150 | Train Time: 1.144s | Train Loss: 0.021980 |
# INFO:root:| Epoch: 096/150 | Train Time: 1.219s | Train Loss: 0.021952 |
# INFO:root:| Epoch: 097/150 | Train Time: 1.056s | Train Loss: 0.022074 |
# INFO:root:| Epoch: 098/150 | Train Time: 1.257s | Train Loss: 0.022076 |
# INFO:root:| Epoch: 099/150 | Train Time: 1.154s | Train Loss: 0.022054 |
# INFO:root:| Epoch: 100/150 | Train Time: 1.186s | Train Loss: 0.021776 |
# INFO:root:  LR scheduler: new learning rate is 1e-05
# INFO:root:| Epoch: 101/150 | Train Time: 1.203s | Train Loss: 0.021755 |
# INFO:root:| Epoch: 102/150 | Train Time: 1.162s | Train Loss: 0.021616 |
# INFO:root:| Epoch: 103/150 | Train Time: 1.174s | Train Loss: 0.021603 |
# INFO:root:| Epoch: 104/150 | Train Time: 1.224s | Train Loss: 0.021565 |
# INFO:root:| Epoch: 105/150 | Train Time: 1.095s | Train Loss: 0.021615 |
# INFO:root:| Epoch: 106/150 | Train Time: 1.132s | Train Loss: 0.021694 |
# INFO:root:| Epoch: 107/150 | Train Time: 1.050s | Train Loss: 0.021627 |
# INFO:root:| Epoch: 108/150 | Train Time: 1.179s | Train Loss: 0.021516 |
# INFO:root:| Epoch: 109/150 | Train Time: 1.186s | Train Loss: 0.021645 |
# INFO:root:| Epoch: 110/150 | Train Time: 1.086s | Train Loss: 0.021655 |
# INFO:root:| Epoch: 111/150 | Train Time: 1.101s | Train Loss: 0.021432 |
# INFO:root:| Epoch: 112/150 | Train Time: 1.209s | Train Loss: 0.021578 |
# INFO:root:| Epoch: 113/150 | Train Time: 1.055s | Train Loss: 0.021584 |
# INFO:root:| Epoch: 114/150 | Train Time: 1.260s | Train Loss: 0.021576 |
# INFO:root:| Epoch: 115/150 | Train Time: 1.230s | Train Loss: 0.021565 |
# INFO:root:| Epoch: 116/150 | Train Time: 1.022s | Train Loss: 0.021599 |
# INFO:root:| Epoch: 117/150 | Train Time: 1.165s | Train Loss: 0.021504 |
# INFO:root:| Epoch: 118/150 | Train Time: 1.149s | Train Loss: 0.021535 |
# INFO:root:| Epoch: 119/150 | Train Time: 1.122s | Train Loss: 0.021645 |
# INFO:root:| Epoch: 120/150 | Train Time: 1.237s | Train Loss: 0.021472 |
# INFO:root:| Epoch: 121/150 | Train Time: 1.206s | Train Loss: 0.021595 |
# INFO:root:| Epoch: 122/150 | Train Time: 1.141s | Train Loss: 0.021483 |
# INFO:root:| Epoch: 123/150 | Train Time: 1.262s | Train Loss: 0.021449 |
# INFO:root:| Epoch: 124/150 | Train Time: 1.175s | Train Loss: 0.021424 |
# INFO:root:| Epoch: 125/150 | Train Time: 1.190s | Train Loss: 0.021408 |
# INFO:root:| Epoch: 126/150 | Train Time: 1.220s | Train Loss: 0.021516 |
# INFO:root:| Epoch: 127/150 | Train Time: 1.105s | Train Loss: 0.021444 |
# INFO:root:| Epoch: 128/150 | Train Time: 1.207s | Train Loss: 0.021463 |
# INFO:root:| Epoch: 129/150 | Train Time: 1.200s | Train Loss: 0.021518 |
# INFO:root:| Epoch: 130/150 | Train Time: 1.199s | Train Loss: 0.021459 |
# INFO:root:| Epoch: 131/150 | Train Time: 1.147s | Train Loss: 0.021544 |
# INFO:root:| Epoch: 132/150 | Train Time: 1.122s | Train Loss: 0.021317 |
# INFO:root:| Epoch: 133/150 | Train Time: 1.113s | Train Loss: 0.021299 |
# INFO:root:| Epoch: 134/150 | Train Time: 1.088s | Train Loss: 0.021549 |
# INFO:root:| Epoch: 135/150 | Train Time: 1.137s | Train Loss: 0.021600 |
# INFO:root:| Epoch: 136/150 | Train Time: 1.086s | Train Loss: 0.021528 |
# INFO:root:| Epoch: 137/150 | Train Time: 1.155s | Train Loss: 0.021423 |
# INFO:root:| Epoch: 138/150 | Train Time: 1.164s | Train Loss: 0.021462 |
# INFO:root:| Epoch: 139/150 | Train Time: 1.154s | Train Loss: 0.021509 |
# INFO:root:| Epoch: 140/150 | Train Time: 1.122s | Train Loss: 0.021476 |
# INFO:root:| Epoch: 141/150 | Train Time: 1.260s | Train Loss: 0.021282 |
# INFO:root:| Epoch: 142/150 | Train Time: 1.199s | Train Loss: 0.021466 |
# INFO:root:| Epoch: 143/150 | Train Time: 1.091s | Train Loss: 0.021386 |
# INFO:root:| Epoch: 144/150 | Train Time: 1.075s | Train Loss: 0.021614 |
# INFO:root:| Epoch: 145/150 | Train Time: 1.132s | Train Loss: 0.021479 |
# INFO:root:| Epoch: 146/150 | Train Time: 1.215s | Train Loss: 0.021634 |
# INFO:root:| Epoch: 147/150 | Train Time: 1.175s | Train Loss: 0.021438 |
# INFO:root:| Epoch: 148/150 | Train Time: 1.070s | Train Loss: 0.021511 |
# INFO:root:| Epoch: 149/150 | Train Time: 1.070s | Train Loss: 0.021352 |
# INFO:root:| Epoch: 150/150 | Train Time: 1.167s | Train Loss: 0.021358 |
# INFO:root:Pretraining Time: 166.928s
# INFO:root:Finished pretraining.
# INFO:root:Testing autoencoder...
# INFO:root:Test Loss: 0.020312
# INFO:root:Test Time: 0.234s
# INFO:root:Finished testing autoencoder.
# INFO:root:Hey I am loading net for you!
# INFO:root:Setting hyper-parameters!
# INFO:root:Initializing center c...
# Learning rate: 0.0001
# INFO:root:Center c initialized.
# INFO:root:Starting training...
# INFO:root:| Epoch: 001/150 | Train Time: 1.038s | Train Loss: 0.063045 |
# INFO:root:| Epoch: 002/150 | Train Time: 0.980s | Train Loss: 0.019090 |
# INFO:root:| Epoch: 003/150 | Train Time: 1.065s | Train Loss: 0.013020 |
# INFO:root:| Epoch: 004/150 | Train Time: 0.957s | Train Loss: 0.010783 |
# INFO:root:| Epoch: 005/150 | Train Time: 0.971s | Train Loss: 0.008167 |
# INFO:root:| Epoch: 006/150 | Train Time: 0.957s | Train Loss: 0.008411 |
# INFO:root:| Epoch: 007/150 | Train Time: 1.094s | Train Loss: 0.006742 |
# INFO:root:| Epoch: 008/150 | Train Time: 0.980s | Train Loss: 0.006359 |
# INFO:root:| Epoch: 009/150 | Train Time: 1.071s | Train Loss: 0.005661 |
# INFO:root:| Epoch: 010/150 | Train Time: 1.001s | Train Loss: 0.005400 |
# INFO:root:| Epoch: 011/150 | Train Time: 1.034s | Train Loss: 0.004781 |
# INFO:root:| Epoch: 012/150 | Train Time: 1.025s | Train Loss: 0.004571 |
# INFO:root:| Epoch: 013/150 | Train Time: 1.099s | Train Loss: 0.004171 |
# INFO:root:| Epoch: 014/150 | Train Time: 1.052s | Train Loss: 0.004127 |
# INFO:root:| Epoch: 015/150 | Train Time: 1.085s | Train Loss: 0.003816 |
# INFO:root:| Epoch: 016/150 | Train Time: 1.063s | Train Loss: 0.003329 |
# INFO:root:| Epoch: 017/150 | Train Time: 0.981s | Train Loss: 0.003579 |
# INFO:root:| Epoch: 018/150 | Train Time: 0.975s | Train Loss: 0.003483 |
# INFO:root:| Epoch: 019/150 | Train Time: 0.961s | Train Loss: 0.003203 |
# INFO:root:| Epoch: 020/150 | Train Time: 0.976s | Train Loss: 0.002861 |
# INFO:root:| Epoch: 021/150 | Train Time: 1.084s | Train Loss: 0.002896 |
# INFO:root:| Epoch: 022/150 | Train Time: 1.080s | Train Loss: 0.003075 |
# INFO:root:| Epoch: 023/150 | Train Time: 0.997s | Train Loss: 0.002518 |
# INFO:root:| Epoch: 024/150 | Train Time: 1.030s | Train Loss: 0.002558 |
# INFO:root:| Epoch: 025/150 | Train Time: 1.040s | Train Loss: 0.002626 |
# INFO:root:| Epoch: 026/150 | Train Time: 0.917s | Train Loss: 0.002462 |
# INFO:root:| Epoch: 027/150 | Train Time: 1.030s | Train Loss: 0.002189 |
# INFO:root:| Epoch: 028/150 | Train Time: 0.991s | Train Loss: 0.002147 |
# INFO:root:| Epoch: 029/150 | Train Time: 1.010s | Train Loss: 0.002255 |
# INFO:root:| Epoch: 030/150 | Train Time: 1.069s | Train Loss: 0.001936 |
# INFO:root:| Epoch: 031/150 | Train Time: 0.887s | Train Loss: 0.001934 |
# INFO:root:| Epoch: 032/150 | Train Time: 1.059s | Train Loss: 0.001917 |
# INFO:root:| Epoch: 033/150 | Train Time: 0.985s | Train Loss: 0.001787 |
# INFO:root:| Epoch: 034/150 | Train Time: 0.989s | Train Loss: 0.002092 |
# INFO:root:| Epoch: 035/150 | Train Time: 1.015s | Train Loss: 0.001760 |
# INFO:root:| Epoch: 036/150 | Train Time: 1.069s | Train Loss: 0.001682 |
# INFO:root:| Epoch: 037/150 | Train Time: 1.004s | Train Loss: 0.001736 |
# INFO:root:| Epoch: 038/150 | Train Time: 1.018s | Train Loss: 0.001604 |
# INFO:root:| Epoch: 039/150 | Train Time: 1.024s | Train Loss: 0.001529 |
# INFO:root:| Epoch: 040/150 | Train Time: 0.954s | Train Loss: 0.001445 |
# INFO:root:| Epoch: 041/150 | Train Time: 1.102s | Train Loss: 0.001510 |
# INFO:root:| Epoch: 042/150 | Train Time: 1.068s | Train Loss: 0.001666 |
# INFO:root:| Epoch: 043/150 | Train Time: 1.011s | Train Loss: 0.001467 |
# INFO:root:| Epoch: 044/150 | Train Time: 1.047s | Train Loss: 0.001252 |
# INFO:root:| Epoch: 045/150 | Train Time: 0.900s | Train Loss: 0.001456 |
# INFO:root:| Epoch: 046/150 | Train Time: 1.002s | Train Loss: 0.001474 |
# INFO:root:| Epoch: 047/150 | Train Time: 0.976s | Train Loss: 0.001435 |
# INFO:root:| Epoch: 048/150 | Train Time: 1.007s | Train Loss: 0.001258 |
# INFO:root:| Epoch: 049/150 | Train Time: 1.098s | Train Loss: 0.001283 |
# INFO:root:| Epoch: 050/150 | Train Time: 0.995s | Train Loss: 0.001133 |
# INFO:root:  LR scheduler: new learning rate is 1e-06
# INFO:root:| Epoch: 051/150 | Train Time: 1.055s | Train Loss: 0.001146 |
# INFO:root:| Epoch: 052/150 | Train Time: 0.979s | Train Loss: 0.001059 |
# INFO:root:| Epoch: 053/150 | Train Time: 0.944s | Train Loss: 0.001103 |
# INFO:root:| Epoch: 054/150 | Train Time: 0.931s | Train Loss: 0.001061 |
# INFO:root:| Epoch: 055/150 | Train Time: 0.923s | Train Loss: 0.001029 |
# INFO:root:| Epoch: 056/150 | Train Time: 0.986s | Train Loss: 0.000926 |
# INFO:root:| Epoch: 057/150 | Train Time: 0.977s | Train Loss: 0.001008 |
# INFO:root:| Epoch: 058/150 | Train Time: 0.916s | Train Loss: 0.000981 |
# INFO:root:| Epoch: 059/150 | Train Time: 0.861s | Train Loss: 0.001063 |
# INFO:root:| Epoch: 060/150 | Train Time: 0.941s | Train Loss: 0.001036 |
# INFO:root:| Epoch: 061/150 | Train Time: 0.887s | Train Loss: 0.001060 |
# INFO:root:| Epoch: 062/150 | Train Time: 0.950s | Train Loss: 0.001006 |
# INFO:root:| Epoch: 063/150 | Train Time: 0.971s | Train Loss: 0.001055 |
# INFO:root:| Epoch: 064/150 | Train Time: 0.949s | Train Loss: 0.000983 |
# INFO:root:| Epoch: 065/150 | Train Time: 0.860s | Train Loss: 0.001227 |
# INFO:root:| Epoch: 066/150 | Train Time: 0.974s | Train Loss: 0.000939 |
# INFO:root:| Epoch: 067/150 | Train Time: 0.863s | Train Loss: 0.001015 |
# INFO:root:| Epoch: 068/150 | Train Time: 0.856s | Train Loss: 0.001049 |
# INFO:root:| Epoch: 069/150 | Train Time: 0.956s | Train Loss: 0.001047 |
# INFO:root:| Epoch: 070/150 | Train Time: 0.857s | Train Loss: 0.001083 |
# INFO:root:| Epoch: 071/150 | Train Time: 0.883s | Train Loss: 0.000959 |
# INFO:root:| Epoch: 072/150 | Train Time: 0.958s | Train Loss: 0.000894 |
# INFO:root:| Epoch: 073/150 | Train Time: 0.978s | Train Loss: 0.001024 |
# INFO:root:| Epoch: 074/150 | Train Time: 0.879s | Train Loss: 0.001019 |
# INFO:root:| Epoch: 075/150 | Train Time: 0.948s | Train Loss: 0.000962 |
# INFO:root:| Epoch: 076/150 | Train Time: 0.883s | Train Loss: 0.000981 |
# INFO:root:| Epoch: 077/150 | Train Time: 0.869s | Train Loss: 0.000969 |
# INFO:root:| Epoch: 078/150 | Train Time: 0.957s | Train Loss: 0.001189 |
# INFO:root:| Epoch: 079/150 | Train Time: 0.917s | Train Loss: 0.001088 |
# INFO:root:| Epoch: 080/150 | Train Time: 0.901s | Train Loss: 0.001131 |
# INFO:root:| Epoch: 081/150 | Train Time: 0.856s | Train Loss: 0.000969 |
# INFO:root:| Epoch: 082/150 | Train Time: 0.886s | Train Loss: 0.000926 |
# INFO:root:| Epoch: 083/150 | Train Time: 0.854s | Train Loss: 0.000891 |
# INFO:root:| Epoch: 084/150 | Train Time: 0.945s | Train Loss: 0.000907 |
# INFO:root:| Epoch: 085/150 | Train Time: 0.877s | Train Loss: 0.000950 |
# INFO:root:| Epoch: 086/150 | Train Time: 0.859s | Train Loss: 0.001122 |
# INFO:root:| Epoch: 087/150 | Train Time: 0.911s | Train Loss: 0.001011 |
# INFO:root:| Epoch: 088/150 | Train Time: 0.889s | Train Loss: 0.000942 |
# INFO:root:| Epoch: 089/150 | Train Time: 0.848s | Train Loss: 0.000933 |
# INFO:root:| Epoch: 090/150 | Train Time: 0.893s | Train Loss: 0.000962 |
# INFO:root:| Epoch: 091/150 | Train Time: 0.860s | Train Loss: 0.000848 |
# INFO:root:| Epoch: 092/150 | Train Time: 0.871s | Train Loss: 0.000826 |
# INFO:root:| Epoch: 093/150 | Train Time: 0.889s | Train Loss: 0.000802 |
# INFO:root:| Epoch: 094/150 | Train Time: 0.905s | Train Loss: 0.000888 |
# INFO:root:| Epoch: 095/150 | Train Time: 0.878s | Train Loss: 0.000819 |
# INFO:root:| Epoch: 096/150 | Train Time: 0.901s | Train Loss: 0.000834 |
# INFO:root:| Epoch: 097/150 | Train Time: 0.920s | Train Loss: 0.000900 |
# INFO:root:| Epoch: 098/150 | Train Time: 0.878s | Train Loss: 0.000894 |
# INFO:root:| Epoch: 099/150 | Train Time: 0.909s | Train Loss: 0.000783 |
# INFO:root:| Epoch: 100/150 | Train Time: 0.831s | Train Loss: 0.000876 |
# INFO:root:  LR scheduler: new learning rate is 1e-07
# INFO:root:| Epoch: 101/150 | Train Time: 0.885s | Train Loss: 0.000874 |
# INFO:root:| Epoch: 102/150 | Train Time: 0.901s | Train Loss: 0.001028 |
# INFO:root:| Epoch: 103/150 | Train Time: 0.903s | Train Loss: 0.000805 |
# INFO:root:| Epoch: 104/150 | Train Time: 0.948s | Train Loss: 0.000871 |
# INFO:root:| Epoch: 105/150 | Train Time: 0.899s | Train Loss: 0.000827 |
# INFO:root:| Epoch: 106/150 | Train Time: 0.877s | Train Loss: 0.000839 |
# INFO:root:| Epoch: 107/150 | Train Time: 0.862s | Train Loss: 0.000888 |
# INFO:root:| Epoch: 108/150 | Train Time: 0.933s | Train Loss: 0.000874 |
# INFO:root:| Epoch: 109/150 | Train Time: 0.868s | Train Loss: 0.000949 |
# INFO:root:| Epoch: 110/150 | Train Time: 0.859s | Train Loss: 0.000916 |
# INFO:root:| Epoch: 111/150 | Train Time: 0.904s | Train Loss: 0.000785 |
# INFO:root:| Epoch: 112/150 | Train Time: 0.906s | Train Loss: 0.000822 |
# INFO:root:| Epoch: 113/150 | Train Time: 0.897s | Train Loss: 0.000836 |
# INFO:root:| Epoch: 114/150 | Train Time: 0.863s | Train Loss: 0.000882 |
# INFO:root:| Epoch: 115/150 | Train Time: 0.911s | Train Loss: 0.000777 |
# INFO:root:| Epoch: 116/150 | Train Time: 0.918s | Train Loss: 0.001046 |
# INFO:root:| Epoch: 117/150 | Train Time: 0.876s | Train Loss: 0.000802 |
# INFO:root:| Epoch: 118/150 | Train Time: 0.855s | Train Loss: 0.000791 |
# INFO:root:| Epoch: 119/150 | Train Time: 0.887s | Train Loss: 0.000785 |
# INFO:root:| Epoch: 120/150 | Train Time: 0.849s | Train Loss: 0.000843 |
# INFO:root:| Epoch: 121/150 | Train Time: 0.858s | Train Loss: 0.000801 |
# INFO:root:| Epoch: 122/150 | Train Time: 0.898s | Train Loss: 0.000949 |
# INFO:root:| Epoch: 123/150 | Train Time: 0.873s | Train Loss: 0.000860 |
# INFO:root:| Epoch: 124/150 | Train Time: 0.865s | Train Loss: 0.001049 |
# INFO:root:| Epoch: 125/150 | Train Time: 0.844s | Train Loss: 0.000845 |
# INFO:root:| Epoch: 126/150 | Train Time: 0.918s | Train Loss: 0.000780 |
# INFO:root:| Epoch: 127/150 | Train Time: 1.008s | Train Loss: 0.001000 |
# INFO:root:| Epoch: 128/150 | Train Time: 0.830s | Train Loss: 0.001743 |
# INFO:root:| Epoch: 129/150 | Train Time: 0.872s | Train Loss: 0.000820 |
# INFO:root:| Epoch: 130/150 | Train Time: 0.915s | Train Loss: 0.000828 |
# INFO:root:| Epoch: 131/150 | Train Time: 0.864s | Train Loss: 0.000950 |
# INFO:root:| Epoch: 132/150 | Train Time: 0.877s | Train Loss: 0.000816 |
# INFO:root:| Epoch: 133/150 | Train Time: 0.943s | Train Loss: 0.000816 |
# INFO:root:| Epoch: 134/150 | Train Time: 0.855s | Train Loss: 0.000811 |
# INFO:root:| Epoch: 135/150 | Train Time: 0.905s | Train Loss: 0.000870 |
# INFO:root:| Epoch: 136/150 | Train Time: 0.845s | Train Loss: 0.000842 |
# INFO:root:| Epoch: 137/150 | Train Time: 0.898s | Train Loss: 0.000883 |
# INFO:root:| Epoch: 138/150 | Train Time: 0.888s | Train Loss: 0.000841 |
# INFO:root:| Epoch: 139/150 | Train Time: 0.966s | Train Loss: 0.000849 |
# INFO:root:| Epoch: 140/150 | Train Time: 0.887s | Train Loss: 0.000762 |
# INFO:root:| Epoch: 141/150 | Train Time: 0.910s | Train Loss: 0.000816 |
# INFO:root:| Epoch: 142/150 | Train Time: 0.873s | Train Loss: 0.000940 |
# INFO:root:| Epoch: 143/150 | Train Time: 0.897s | Train Loss: 0.000785 |
# INFO:root:| Epoch: 144/150 | Train Time: 0.848s | Train Loss: 0.000816 |
# INFO:root:| Epoch: 145/150 | Train Time: 0.884s | Train Loss: 0.000851 |
# INFO:root:| Epoch: 146/150 | Train Time: 0.877s | Train Loss: 0.001128 |
# INFO:root:| Epoch: 147/150 | Train Time: 0.872s | Train Loss: 0.000860 |
# INFO:root:| Epoch: 148/150 | Train Time: 0.889s | Train Loss: 0.000834 |
# INFO:root:| Epoch: 149/150 | Train Time: 0.962s | Train Loss: 0.000873 |
# INFO:root:| Epoch: 150/150 | Train Time: 0.862s | Train Loss: 0.000760 |
# INFO:root:Training Time: 140.920s
# INFO:root:Finished training.

# %%
model.test(dataset, device, n_jobs_dataloader, label_normal)
# Out:
# INFO:root:Starting testing...
# INFO:root:Test Loss: 0.003930
# INFO:root:Test AUC: 100.00%
# INFO:root:Test Time: 0.213s
# INFO:root:Finished testing.

# %%
model.save_model(export_model=model_path, save_ae=save_ae)

# %%
indices_, labels_, scores_ = zip(*model.results['test_scores'])
indices_, labels_, scores_ = np.array(indices_), np.array(labels_), np.array(scores_)
result_df = pd.DataFrame()
result_df['indices'] = indices_; result_df['labels'] = labels_; result_df['scores'] = scores_

result_df.drop('indices', inplace=True, axis=1)
df_normal = result_df[result_df.labels.isin(label_normal)]
df_abnormal = result_df[result_df.labels.isin(label_abnormal)]

cut_90 = df_normal.scores.quantile(0.90)
# np.save(cut_90_path, cut_90)

cut_95 = df_normal.scores.quantile(0.95)
# np.save(cut_95_path, cut_95)

cut_99 = df_normal.scores.quantile(0.99)
# np.save(cut_99_path, cut_99)

# %%
label_eval_list = [(i,) for i in range(10)]
total_roc_auc = []
total_recall_90 = []
total_recall_95 = []
total_recall_99 = []

for label_eval in label_eval_list:
    # Formating the path
    test_eval = False
    if (label_eval[0] in label_normal) or (label_eval[0] in label_abnormal):
        test_eval = True
        
    # Start evaluating
    dataset_eval = load_dataset(loader_name=loader_eval_name,
                                root=root,
                                label_eval=label_eval,
                                test_eval=test_eval)

    # Load model for evaluation
    if optimizer_ in ['one_class', 'one_class_unsupervised']:
        model_eval = OneClassModelEval(optimizer_, eta=eta)
    elif optimizer_ in ['rec', 'rec_unsupervised']:
        model_eval = RecModelEval(optimizer_, eta=eta)

    model_eval.set_network(net_name)
    model_eval.load_model(model_path=model_path, map_location=device)
    model_eval.test(dataset_eval,
                    eta=eta,
                    batch_size=batch_size,
                    device=device,
                    n_jobs_dataloader=n_jobs_dataloader,
                    label_normal=label_normal)
    _, labels, scores = zip(*model_eval.results['test_scores'])

    # Get predicted label
    y_90 = [1 if e > cut_90 else 0 for e in scores]
    y_95 = [1 if e > cut_95 else 0 for e in scores]
    y_99 = [1 if e > cut_99 else 0 for e in scores]

    if label_eval[0] in label_normal:
        print('Skip self!')
    else:
        # Record results when FP = 0.10
        recall_90 = sum(y_90) / len(y_90)
        total_recall_90.append(recall_90)
        msg = '[Recall for class {} (FP = 0.10)] {}\n'.format(label_eval[0], recall_90)
        print(msg)
        
        # Record results when FP = 0.05
        recall_95 = sum(y_95) / len(y_95)
        total_recall_95.append(recall_95)
        msg = '[Recall for class {} (FP = 0.05)] {}\n'.format(label_eval[0], recall_95)
        print(msg)
# Out:
# Starting evaluating...
# Test Loss: 0.002840
# Test Time: 0.105s
# Finished testing.
# Skip self!
# Starting evaluating...
# Test Loss: 500.766680
# Test Time: 0.842s
# Finished testing.
# [Recall for class 1 (FP = 0.10)] 0.3922857142857143
#
# [Recall for class 1 (FP = 0.05)] 0.25114285714285717
#
# Starting evaluating...
# Test Loss: 535.344340
# Test Time: 0.757s
# Finished testing.
# [Recall for class 2 (FP = 0.10)] 0.30842857142857144
#
# [Recall for class 2 (FP = 0.05)] 0.1662857142857143
#
# Starting evaluating...
# Test Loss: 611.017788
# Test Time: 0.755s
# Finished testing.
# [Recall for class 3 (FP = 0.10)] 0.2867142857142857
#
# [Recall for class 3 (FP = 0.05)] 0.14814285714285713
#
# Starting evaluating...
# Test Loss: 472.721209
# Test Time: 0.790s
# Finished testing.
# [Recall for class 4 (FP = 0.10)] 0.32871428571428574
#
# [Recall for class 4 (FP = 0.05)] 0.17585714285714285
#
# Starting evaluating...
# Test Loss: 0.638437
# Test Time: 0.760s
# Finished testing.
# [Recall for class 5 (FP = 0.10)] 0.999
#
# [Recall for class 5 (FP = 0.05)] 0.9985714285714286
#
# Starting evaluating...
# Test Loss: 782.456453
# Test Time: 0.759s
# Finished testing.
# [Recall for class 6 (FP = 0.10)] 0.25742857142857145
#
# [Recall for class 6 (FP = 0.05)] 0.141
#
# Starting evaluating...
# Test Loss: 0.004910
# Test Time: 0.119s
# Finished testing.
# [Recall for class 7 (FP = 0.10)] 1.0
#
# [Recall for class 7 (FP = 0.05)] 1.0
#
# Starting evaluating...
# Test Loss: 91.718113
# Test Time: 0.757s
# Finished testing.
# [Recall for class 8 (FP = 0.10)] 0.883
#
# [Recall for class 8 (FP = 0.05)] 0.8185714285714286
#
# Starting evaluating...
# Test Loss: 0.136558
# Test Time: 0.768s
# Finished testing.
# [Recall for class 9 (FP = 0.10)] 0.9995714285714286
#
# [Recall for class 9 (FP = 0.05)] 0.9992857142857143

# %% [markdown]
# Training results is good! Seems that even if the latent dimensions have been compressed to just 2, it can still do works.

# %% [markdown]
# # 3. Extract the Encoder Part

# %%
class OneClassEncoder:
    def __init__(self):
        self.net = None
        self.net_name = None

    def set_network(self, net_name):
        self.net_name = net_name
        self.net = build_network(net_name)

    def load_model(self, model_path, map_location):
        model_dict = torch.load(model_path, map_location=map_location)
        self.c = model_dict['c']
        self.net.load_state_dict(model_dict['net_dict'])

    def test(self, dataset, device, batch_size, n_jobs_dataloader):
        all_loader = dataset.loaders(batch_size=batch_size,
                                     num_workers=n_jobs_dataloader)
        net = self.net.to(device)
        criterion = nn.MSELoss(reduction='none')
        
        n_batches = 0
        X_pred_list = []
        net.eval()
        
        with torch.no_grad():
            for data in all_loader:
                X, y, idx = data
                X, y, idx = X.to(device), y.to(device), idx.to(device)

                X_pred = net(X)
                X_pred_list += X_pred
        
        return np.array(X_pred_list)

# %%
encoder = OneClassEncoder()
encoder.set_network(net_name)

# %%
loader_eval_name = 'kmnist_eval'
root_eval = '/net/leksai/data/KMNIST'
label_eval_list = [(i,) for i in range(10)]
dataset_eval_list = []
for label_eval in label_eval_list:
    dataset_eval_list.append(load_dataset(loader_name=loader_eval_name,
                                          root=root_eval,
                                          label_eval=label_eval,
                                          test_eval=False))

data_list = []
for dataset_eval in dataset_eval_list:
    data = encoder.test(dataset_eval, device, batch_size, n_jobs_dataloader)
    data = np.array([x.cpu().numpy() for x in data])
    data_list.append(data.T)

normal_dataset = load_dataset(loader_name='fmnist_eval',
                                          root=root,
                                          label_eval=(0,),
                                          test_eval=False)
normal_data = encoder.test(normal_dataset, device, batch_size, n_jobs_dataloader)
normal_data = np.array([x.cpu().numpy() for x in normal_data]).T

abnormal_dataset = load_dataset(loader_name='fmnist_eval',
                                          root=root,
                                          label_eval=(7,),
                                          test_eval=False)
abnormal_data = encoder.test(abnormal_dataset, device, batch_size, n_jobs_dataloader)
abnormal_data = np.array([x.cpu().numpy() for x in abnormal_data]).T

num_to_letter = {0:'o', 1:'ki', 2:'su', 3:'tsu', 4:'na', 5:'ha', 6:'ma', 7:'ya', 8:'re', 9:'wo'}

letter_to_num = {v:k for k, v in num_to_letter.items()}

fig, ax = plt.subplots(figsize=(20, 10))

for letter in letter_to_num:
    label = letter_to_num[letter]
    data = data_list[label]
    cluster = sns.scatterplot(x=data[0], y=data[1], label=letter, alpha=0.2, color=sns.color_palette("hls", 12)[2:][label])

cluster = sns.scatterplot(x=abnormal_data[0], y=abnormal_data[1], label='abnormal data (sneaker)', alpha=0.2, color='gold')
cluster = sns.scatterplot(x=normal_data[0], y=normal_data[1], label='normal data (tshirt)', alpha=0.2, color='black')

    
plt.legend()
plt.title('Semi-supervised One Class Model Using tshirt as Normal and sneaker as Abnormal (most different)')
# plt.ylim(-0.04, 0.08)
# plt.xlim(-0.04, 0.10)
sns.despine()

# %%
dataset_eval_list = []
for label_eval in label_eval_list:
    dataset_eval_list.append(load_dataset(loader_name=loader_eval_name,
                                          root=root,
                                          label_eval=label_eval,
                                          test_eval=False))

# %%
data_list = []
for dataset_eval in dataset_eval_list:
    data = encoder.test(dataset_eval, device, batch_size, n_jobs_dataloader)
    data = np.array([x.cpu().numpy() for x in data])
    data_list.append(data.T)

# %%
color_dict = {'tshirt':0,
              'shirt': 1,
              'dress':2,
              'pullover':3,
              'coat':4,
              'trouser':5,
               'bag': 6,
              'boot': 7,
              'sandal': 8,
              'sneaker':9}

num_to_letter ={0: 'tshirt', 
                1: 'trouser', 
                2: 'pullover', 
                3: 'dress', 
                4: 'coat',
                5: 'sandal', 
                6: 'shirt', 
                7: 'sneaker', 
                8: 'bag', 
                9: 'boot'}

letter_to_num = {v:k for k, v in num_to_letter.items()}

fig, ax = plt.subplots(figsize=(20, 10))

for letter in list(color_dict)[::-1]:
    label = letter_to_num[letter]
    data = data_list[label]
    cluster = sns.scatterplot(x=data[0], y=data[1], label=letter, alpha=0.2, color=sns.color_palette("hls", 12)[2:][color_dict[letter]])

plt.legend()
plt.title('Semi-supervised One Class Model Using tshirt as Normal and sneaker as Abnormal (most different)')
plt.ylim(-0.055, 0.20)
plt.xlim(-0.25, 0.10)
sns.despine()

# %%
fig, ax = plt.subplots(figsize=(20, 10))

for i, data in enumerate(data_list):
    cluster = sns.scatterplot(x=data[0], y=data[1], label=label_dict[i], alpha=0.2, color=sns.color_palette("hls", 10)[i])

plt.legend()
plt.title('Semi-supervised One Class Model Using tshirt as Normal and sneaker as Abnormal (most different)')
plt.ylim(-0.055, 0.20)
plt.xlim(-0.25, 0.10)
sns.despine()
