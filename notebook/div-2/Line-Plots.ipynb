# %%
import line_plot_oc
import line_plot_rec
# %config InlineBackend.figure_format='retina'

# %%
identifier = 2

# %%
line_plot_oc.f_00_10(identifier)
line_plot_oc.f_10_20(identifier)
line_plot_oc.f_20_30(identifier)
line_plot_oc.f_30_40(identifier)
line_plot_oc.f_40_50(identifier)
line_plot_oc.f_50_00(identifier)

# %%
line_plot_rec.f_00_10(identifier)
line_plot_rec.f_10_20(identifier)
line_plot_rec.f_20_30(identifier)
line_plot_rec.f_30_40(identifier)
line_plot_rec.f_40_50(identifier)
line_plot_rec.f_50_00(identifier)
