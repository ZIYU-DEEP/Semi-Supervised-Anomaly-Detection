# %%
from PLOT_ import *

# %config InlineBackend.figure_format='retina'
identifier = 8

# %% [markdown]
# ## 1. Recall v.s. $\frac {KL(P_1, P_i)} {KL(P_0, P_1)}$

# %%
show_division(identifier, metric='recall', axis_start=-0.1, axis_end=2.5)

# %% [markdown]
# ## 2. F1 v.s. $KL(P_{0} || P_{1}) + KL(P_{0} || P^{'}_{1}) - KL(P_1 || P_i)$

# %%
show_triangle(identifier, metric='recall', axis_start=2, axis_end=105)
